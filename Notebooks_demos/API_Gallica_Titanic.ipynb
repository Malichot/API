# %% [markdown]
# ## API Gallica et recherche documentaire dans la presse : Le naufrage du <i>Titanic</i>

# %% [markdown]
# Le script suit le scénario de recherche documentaire décrit dans ce [tutoriel vidéo](https://www.youtube.com/watch?v=ukBr7qUZvww).

# %% [markdown]
# ### 1. Construire la requête sur le mot-clé "titanic" et appeler l'API SRU Gallica

# %%
# URL de base du service SRU
BASEURL = 'https://gallica.bnf.fr/SRU?version=1.2&operation=searchRetrieve&maximumRecords=50&query='
# URL de base du service ContentSearch
BASESEARCH = 'https://gallica.bnf.fr/services/ContentSearch?ark='
# URL de base Gallica
BASEGALLICA = 'https://gallica.bnf.fr/ark:/12148/'
# URL de base de l'API Gallica IIIF
BASEIIIF ='https://gallica.bnf.fr/iiif/ark:/12148/'
# URL de base du service de calendrier pour les périodiques Gallica
ISSUEURL = 'https://gallica.bnf.fr/services/Issues?ark='
# URL de base du service de facettes 
CATEGORIEURL = 'https://gallica.bnf.fr/services/Categories?SRU='

import requests

# Construire la requête Gallica avec le mot-clé "titanic" en s'aidant de Gallica
# puis recopier la requête suivant le paramètre query=  
req_url = "".join([BASEURL, 'gallica%20all%20%22titanic%22'])
print ("... appel de l'API Gallica SRU : ",req_url)
r = requests.get(req_url)
print (r.status_code)
print (r.encoding)
print (r.text)
# Out:
# ... appel de l'API Gallica SRU :  https://gallica.bnf.fr/SRU?version=1.2&operation=searchRetrieve&maximumRecords=50&query=gallica%20all%20%22titanic%22
# 200
# UTF-8
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <srw:searchRetrieveResponse xmlns:ns5="http://gallica.bnf.fr/namespaces/gallica/" xmlns:oai_dc="http://www.openarchives.org/OAI/2.0/oai_dc/" xmlns:srw="http://www.loc.gov/zing/srw/" xmlns:dc="http://purl.org/dc/elements/1.1/">
#     <srw:version>1.2</srw:version>
#     <srw:echoedSearchRetrieveRequest>
#         <srw:query>gallica all "titanic"</srw:query>
#         <srw:version>1.2</srw:version>
#     </srw:echoedSearchRetrieveRequest>
#     <srw:numberOfRecords>6837</srw:numberOfRecords>
#     <srw:extraResponseData>&lt;numberOfRecordsDecollapser&gt;48068&lt;/numberOfRecordsDecollapser&gt;</srw:extraResponseData>
#     <srw:records>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:coverage>08 avril 1912</dc:coverage>
#                     <dc:creator>Agence de presse Meurisse. Agence photographique</dc:creator>
#                     <dc:date>1912</dc:date>
#                     <dc:description>Référence bibliographique : Meurisse, 23006</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pho20Meu</dc:description>
#                     <dc:description>Image de presse</dc:description>
#                     <dc:format>1 photogr. nég. sur verre ; 13 x 18 cm (sup.) ou moins</dc:format>
#                     <dc:format>image/jpeg</dc:format>
#                     <dc:format>Nombre total de vues : 1</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/btv1b9020648r</dc:identifier>
#                     <dc:identifier>Numéro commercial : Meurisse 23006</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice de recueil : http://catalogue.bnf.fr/ark:/12148/cb40499413n</dc:relation>
#                     <dc:relation>Appartient à : [Recueil. Actualités 1911-06-27**1912-06-16. Agence Meurisse MEU 13813-25459]</dc:relation>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb41568220t</dc:relation>
#                     <dc:rights>domaine public</dc:rights>
#                     <dc:rights>public domain</dc:rights>
#                     <dc:source>Bibliothèque nationale de France, département Estampes et photographie, EI-13 (2475)</dc:source>
#                     <dc:title>Le Titanic : [photographie de presse] / Agence Meurisse</dc:title>
#                     <dc:type>image fixe</dc:type>
#                     <dc:type>image</dc:type>
#                     <dc:type>still image</dc:type>
#                     <dc:type>photographie</dc:type>
#                     <dc:type>photograph</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>0</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/btv1b9020648r</link>
#                 <nqamoyen>0.0</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/btv1b9020648r.thumbnail</thumbnail>
#                 <typedoc>images</typedoc>
#                 <uri>btv1b9020648r</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1943</dc:date>
#                     <dc:description>Contient : coupures de presse</dc:description>
#                     <dc:format>1 rec. factice ( 11 p. ) ; 25 cm</dc:format>
#                     <dc:format>Nombre total de vues : 34</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/btv1b105159728</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb426702583</dc:relation>
#                     <dc:rights>domaine public</dc:rights>
#                     <dc:rights>public domain</dc:rights>
#                     <dc:source>Bibliothèque nationale de France, département Arts du spectacle, 8-RSUPP-1364</dc:source>
#                     <dc:subject>Titanic (film ; 1942)</dc:subject>
#                     <dc:title>[Recueil. "Titanic" film de Werner Klingler et Herbert Selpin]</dc:title>
#                     <dc:type>archival material</dc:type>
#                     <dc:type>document d'archives</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>1</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/btv1b105159728</link>
#                 <nqamoyen>0.0</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/btv1b105159728.thumbnail</thumbnail>
#                 <typedoc>manuscrits</typedoc>
#                 <uri>btv1b105159728</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:coverage>15 avril 1912</dc:coverage>
#                     <dc:creator>Agence Rol. Agence photographique</dc:creator>
#                     <dc:date>1912</dc:date>
#                     <dc:description>Référence bibliographique : Rol, 20238</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pho20Rol</dc:description>
#                     <dc:format>1 photogr. nég. sur verre ; 13 x 18 cm (sup.)</dc:format>
#                     <dc:format>image/jpeg</dc:format>
#                     <dc:format>Nombre total de vues : 1</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/btv1b531142500</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb403398678</dc:relation>
#                     <dc:rights>domaine public</dc:rights>
#                     <dc:rights>public domain</dc:rights>
#                     <dc:source>Bibliothèque nationale de France, département Estampes et photographie, EI-13 (156)</dc:source>
#                     <dc:subject>Titanic (paquebot)</dc:subject>
#                     <dc:subject>Navigation -- Accidents</dc:subject>
#                     <dc:subject>Bateaux de sauvetage</dc:subject>
#                     <dc:subject>Victimes de catastrophes</dc:subject>
#                     <dc:subject>Photographie de presse -- 1900-1945</dc:subject>
#                     <dc:title>Catastrophe du Titanic, les rescapés [dans les canots sur la mer, le 15 avril 1912] : [photographie de presse] / [Agence Rol]</dc:title>
#                     <dc:type>image fixe</dc:type>
#                     <dc:type>image</dc:type>
#                     <dc:type>still image</dc:type>
#                     <dc:type>photographie</dc:type>
#                     <dc:type>photograph</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>2</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/btv1b531142500</link>
#                 <nqamoyen>0.0</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/btv1b531142500.thumbnail</thumbnail>
#                 <typedoc>images</typedoc>
#                 <uri>btv1b531142500</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:coverage>20 avril 1912</dc:coverage>
#                     <dc:creator>Agence Rol. Agence photographique</dc:creator>
#                     <dc:date>1912</dc:date>
#                     <dc:description>Référence bibliographique : Rol, 20230</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pho20Rol</dc:description>
#                     <dc:format>1 photogr. nég. sur verre ; 13 x 18 cm (sup.)</dc:format>
#                     <dc:format>image/jpeg</dc:format>
#                     <dc:format>Nombre total de vues : 1</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/btv1b53114228b</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb40339866x</dc:relation>
#                     <dc:rights>domaine public</dc:rights>
#                     <dc:rights>public domain</dc:rights>
#                     <dc:source>Bibliothèque nationale de France, département Estampes et photographie, EI-13 (156)</dc:source>
#                     <dc:subject>Titanic (paquebot)</dc:subject>
#                     <dc:subject>Navigation -- Accidents</dc:subject>
#                     <dc:subject>Victimes de catastrophes</dc:subject>
#                     <dc:subject>Photographie de presse -- 1900-1945</dc:subject>
#                     <dc:title>Catastrophe du Titanic, les rescapés [20 avril 1912] : [photographie de presse] / [Agence Rol]</dc:title>
#                     <dc:type>image fixe</dc:type>
#                     <dc:type>image</dc:type>
#                     <dc:type>still image</dc:type>
#                     <dc:type>photographie</dc:type>
#                     <dc:type>photograph</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>3</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/btv1b53114228b</link>
#                 <nqamoyen>0.0</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/btv1b53114228b.thumbnail</thumbnail>
#                 <typedoc>images</typedoc>
#                 <uri>btv1b53114228b</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:coverage>.. avril 1912</dc:coverage>
#                     <dc:creator>Agence Rol. Agence photographique</dc:creator>
#                     <dc:date>1912</dc:date>
#                     <dc:description>Référence bibliographique : Rol, 19843</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pho20Rol</dc:description>
#                     <dc:format>1 photogr. nég. sur verre ; 13 x 18 cm (sup.)</dc:format>
#                     <dc:format>image/jpeg</dc:format>
#                     <dc:format>Nombre total de vues : 1</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/btv1b531140185</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb40477110w</dc:relation>
#                     <dc:rights>domaine public</dc:rights>
#                     <dc:rights>public domain</dc:rights>
#                     <dc:source>Bibliothèque nationale de France, département Estampes et photographie, EI-13 (151)</dc:source>
#                     <dc:subject>Smith, Edward John (1850-1912)</dc:subject>
#                     <dc:subject>Titanic (paquebot)</dc:subject>
#                     <dc:subject>Capitaines de navire</dc:subject>
#                     <dc:subject>White Star Line</dc:subject>
#                     <dc:subject>Photographie de presse -- 1900-1945</dc:subject>
#                     <dc:title>Commandant Smith, capitaine du Titanic : [photographie de presse] / [Agence Rol]</dc:title>
#                     <dc:type>image fixe</dc:type>
#                     <dc:type>image</dc:type>
#                     <dc:type>still image</dc:type>
#                     <dc:type>photographie</dc:type>
#                     <dc:type>photograph</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>4</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/btv1b531140185</link>
#                 <nqamoyen>0.0</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/btv1b531140185.thumbnail</thumbnail>
#                 <typedoc>images</typedoc>
#                 <uri>btv1b531140185</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:coverage>.. avril 1912</dc:coverage>
#                     <dc:creator>Agence Rol. Agence photographique</dc:creator>
#                     <dc:date>1912</dc:date>
#                     <dc:description>Référence bibliographique : Rol, 19842</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pho20Rol</dc:description>
#                     <dc:format>1 photogr. nég. sur verre ; 13 x 18 cm (sup.)</dc:format>
#                     <dc:format>image/jpeg</dc:format>
#                     <dc:format>Nombre total de vues : 1</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/btv1b531139884</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb40477109p</dc:relation>
#                     <dc:rights>domaine public</dc:rights>
#                     <dc:rights>public domain</dc:rights>
#                     <dc:source>Bibliothèque nationale de France, département Estampes et photographie, EI-13 (151)</dc:source>
#                     <dc:subject>Phillips, John (1887-1912)</dc:subject>
#                     <dc:subject>Titanic (paquebot)</dc:subject>
#                     <dc:subject>Télégraphie sans fil</dc:subject>
#                     <dc:subject>Télégraphistes</dc:subject>
#                     <dc:subject>White Star Line</dc:subject>
#                     <dc:subject>Photographie de presse -- 1900-1945</dc:subject>
#                     <dc:title>Mr Phillips, télégraphiste du Titanic : [photographie de presse] / [Agence Rol]</dc:title>
#                     <dc:type>image fixe</dc:type>
#                     <dc:type>image</dc:type>
#                     <dc:type>still image</dc:type>
#                     <dc:type>photographie</dc:type>
#                     <dc:type>photograph</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>5</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/btv1b531139884</link>
#                 <nqamoyen>0.0</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/btv1b531139884.thumbnail</thumbnail>
#                 <typedoc>images</typedoc>
#                 <uri>btv1b531139884</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:coverage>20 avril 1912</dc:coverage>
#                     <dc:creator>Agence Rol. Agence photographique</dc:creator>
#                     <dc:date>1912</dc:date>
#                     <dc:description>Référence bibliographique : Rol, 20228</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pho20Rol</dc:description>
#                     <dc:format>1 photogr. nég. sur verre ; 13 x 18 cm (sup.)</dc:format>
#                     <dc:format>image/jpeg</dc:format>
#                     <dc:format>Nombre total de vues : 1</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/btv1b53114251f</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb40339865k</dc:relation>
#                     <dc:rights>domaine public</dc:rights>
#                     <dc:rights>public domain</dc:rights>
#                     <dc:source>Bibliothèque nationale de France, département Estampes et photographie, EI-13 (156)</dc:source>
#                     <dc:subject>Titanic (paquebot)</dc:subject>
#                     <dc:subject>Navigation -- Accidents</dc:subject>
#                     <dc:subject>Ports -- États-Unis -- New York (N.Y.)</dc:subject>
#                     <dc:subject>Navires</dc:subject>
#                     <dc:subject>New York (N.Y.)</dc:subject>
#                     <dc:subject>Carpathia (navire)</dc:subject>
#                     <dc:subject>Photographie de presse -- 1900-1945</dc:subject>
#                     <dc:title>Catastrophe du Titanic, Carpathia à New-York [20 avril 1912] : [photographie de presse] / [Agence Rol]</dc:title>
#                     <dc:type>image fixe</dc:type>
#                     <dc:type>image</dc:type>
#                     <dc:type>still image</dc:type>
#                     <dc:type>photographie</dc:type>
#                     <dc:type>photograph</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>6</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/btv1b53114251f</link>
#                 <nqamoyen>0.0</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/btv1b53114251f.thumbnail</thumbnail>
#                 <typedoc>images</typedoc>
#                 <uri>btv1b53114251f</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:coverage>14 avril 1912</dc:coverage>
#                     <dc:creator>Agence Rol. Agence photographique</dc:creator>
#                     <dc:date>1912</dc:date>
#                     <dc:description>Référence bibliographique : Rol, 19836</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pho20Rol</dc:description>
#                     <dc:format>1 photogr. nég. sur verre ; 13 x 18 cm (sup.)</dc:format>
#                     <dc:format>image/jpeg</dc:format>
#                     <dc:format>Nombre total de vues : 1</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/btv1b531140257</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb404771070</dc:relation>
#                     <dc:rights>domaine public</dc:rights>
#                     <dc:rights>public domain</dc:rights>
#                     <dc:source>Bibliothèque nationale de France, département Estampes et photographie, EI-13 (151)</dc:source>
#                     <dc:subject>Vitrines (magasins) -- France -- Paris (France)</dc:subject>
#                     <dc:subject>White Star Line</dc:subject>
#                     <dc:subject>Titanic (paquebot) -- Modèles réduits</dc:subject>
#                     <dc:subject>Photographie de presse -- 1900-1945</dc:subject>
#                     <dc:title>14-4-12, White Star Line à Paris [à qui appartenait le Titanic, personnes arrêtées devant la vitrine présentant une maquette du bateau] : [photographie de presse] / [Agence Rol]</dc:title>
#                     <dc:type>image fixe</dc:type>
#                     <dc:type>image</dc:type>
#                     <dc:type>still image</dc:type>
#                     <dc:type>photographie</dc:type>
#                     <dc:type>photograph</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>7</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/btv1b531140257</link>
#                 <nqamoyen>0.0</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/btv1b531140257.thumbnail</thumbnail>
#                 <typedoc>images</typedoc>
#                 <uri>btv1b531140257</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:coverage>20 avril 1912</dc:coverage>
#                     <dc:creator>Agence Rol. Agence photographique</dc:creator>
#                     <dc:date>1912</dc:date>
#                     <dc:description>Référence bibliographique : Rol, 19966</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pho20Rol</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : MAEDIGen0</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : MAEDI009</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : MAEDI006</dc:description>
#                     <dc:format>1 photogr. nég. sur verre ; 13 x 18 cm (sup.)</dc:format>
#                     <dc:format>image/jpeg</dc:format>
#                     <dc:format>Nombre total de vues : 1</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/btv1b53114062j</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb40477196f</dc:relation>
#                     <dc:rights>domaine public</dc:rights>
#                     <dc:rights>public domain</dc:rights>
#                     <dc:source>Bibliothèque nationale de France, département Estampes et photographie, EI-13 (152)</dc:source>
#                     <dc:subject>Naufrages</dc:subject>
#                     <dc:subject>Navigation -- Accidents</dc:subject>
#                     <dc:subject>Titanic (paquebot)</dc:subject>
#                     <dc:subject>Victimes de catastrophes</dc:subject>
#                     <dc:subject>Commémorations</dc:subject>
#                     <dc:subject>Ambassadeurs américains -- Grande-Bretagne -- Londres</dc:subject>
#                     <dc:subject>Photographie de presse -- 1900-1945</dc:subject>
#                     <dc:title>Londres, 20-4-12, l'ambassadeur d'Amérique sortant de la cathédrale après l'office aux victimes du Titanic, M. et Mme Rew Leaving : [photographie de presse] / [Agence Rol]</dc:title>
#                     <dc:type>image fixe</dc:type>
#                     <dc:type>image</dc:type>
#                     <dc:type>still image</dc:type>
#                     <dc:type>photographie</dc:type>
#                     <dc:type>photograph</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>8</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/btv1b53114062j</link>
#                 <nqamoyen>0.0</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/btv1b53114062j.thumbnail</thumbnail>
#                 <typedoc>images</typedoc>
#                 <uri>btv1b53114062j</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Defodon, Charles (1832-1891). Directeur de publication</dc:contributor>
#                     <dc:date>1881-1925</dc:date>
#                     <dc:description>Variante(s) de titre : Mon journal et Poupée modèle réunis</dc:description>
#                     <dc:description>Variante(s) de titre : Mon journal : recueil hebdomadaire illustré...</dc:description>
#                     <dc:description>Variante(s) de titre : Mon journal : illustré pour les enfants</dc:description>
#                     <dc:description>Variante(s) de titre : Mon journal</dc:description>
#                     <dc:description>Numérisé par le partenaire</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : UnivJeun0</dc:description>
#                     <dc:description>Avec mode texte</dc:description>
#                     <dc:format>Nombre total de vues : 1010</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32817940n/date</dc:identifier>
#                     <dc:identifier>ISSN 20249748</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32817940n</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Littérature et art, 8-Z-14671 </dc:source>
#                     <dc:title>Mon journal (Paris. 1881)</dc:title>
#                     <dc:title>Mon journal : recueil hebdomadaire illustré pour les enfants de 8 à 12 ans</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>9</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32817940n/date</link>
#                 <nqamoyen>88.59</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k9114750w.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k9114750w</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1894-1914</dc:date>
#                     <dc:description>Etat de collection : Jusqu'à : août 1914 [XXI], inc.</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32753142t/date</dc:identifier>
#                     <dc:identifier>ISSN 20168322</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32753142t</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-40105</dc:source>
#                     <dc:title>La Croix des marins</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>10</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32753142t/date</link>
#                 <nqamoyen>87.46</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k2396005h.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k2396005h</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:creator>Gères, Jules de (1817-1878). Auteur du texte</dc:creator>
#                     <dc:creator>Académie nationale des sciences, belles-lettres et arts (Bordeaux). Auteur du texte</dc:creator>
#                     <dc:date>1860</dc:date>
#                     <dc:description>Variante(s) de titre : Actes de l'Académie impériale des sciences, belles-lettres et arts de Bordeaux</dc:description>
#                     <dc:description>Etat de collection : 3e s., a. 22 (1860)-4e s., a. 7 (1930)</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Aquit1</dc:description>
#                     <dc:format>Nombre total de vues : 34666</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb34363194v/date</dc:identifier>
#                     <dc:identifier>ISSN 02426978</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>E. Dentu (Paris)</dc:publisher>
#                     <dc:publisher>Académie nationale des sciences, belles-lettres et artsAcadémie nationale des sciences, belles-lettres et arts (Bordeaux)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb34363194v</dc:relation>
#                     <dc:source>Bibliothèque nationale de France</dc:source>
#                     <dc:title>Actes de l'Académie nationale des sciences, belles-lettres et arts de Bordeaux</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>11</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb34363194v/date</link>
#                 <nqamoyen>0.0</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k102423s.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k102423s</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:creator>Union républicaine (France). Auteur du texte</dc:creator>
#                     <dc:date>1886-1944</dc:date>
#                     <dc:description>Variante(s) de titre : La Dépêche de Brest et de l'Ouest</dc:description>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GMBrst001</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32755951g/date</dc:identifier>
#                     <dc:identifier>ISSN 21257531</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Brest)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32755951g</dc:relation>
#                     <dc:relation>Première de couverture : 236085</dc:relation>
#                     <dc:source>Bibliothèque municipale de Brest, PB A100</dc:source>
#                     <dc:title>La Dépêche de Brest : journal politique et maritime ["puis" journal de l'Union républicaine "puis" journal républicain quotidien "puis" quotidien républicain du matin]...</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>12</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32755951g/date</link>
#                 <nqamoyen>99.14</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k338340t.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k338340t</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1829-1923</dc:date>
#                     <dc:description>Périodicité : Bihebdomadaire ou trihebdomadaire ; quotidien (9 mars 1848-6 mars 1852, 12 juin-31 oct. 1877, 9 mars 1880-30 juin 1923)</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : PrnS001</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328139024/date</dc:identifier>
#                     <dc:identifier>ISSN 12615919</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Pau)</dc:publisher>
#                     <dc:publisher>[s.n.][s.n.] (Pau)</dc:publisher>
#                     <dc:relation>Notice d'ensemble : http://catalogue.bnf.fr/ark:/12148/cb328139024</dc:relation>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328139024</dc:relation>
#                     <dc:relation>Première de couverture : 309697</dc:relation>
#                     <dc:source>Archives et bibliothèques Pau Béarn Pyrénées - Bibliothèque de Pau, Ee 1609</dc:source>
#                     <dc:title>Le Mémorial des Pyrénées : politique, judiciaire, industriel et d'annonces</dc:title>
#                     <dc:title>Le Mémorial des Pyrénées (Pau)</dc:title>
#                     <dc:title>Le Mémorial des Pyrénées : politique, judiciaire, industriel et d'annonces</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>13</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb328139024/date</link>
#                 <nqamoyen>80.92</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k52473565.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k52473565</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1903-1927</dc:date>
#                     <dc:description>Variante(s) de titre : Absorbé par "Le Courrier de la Manche"</dc:description>
#                     <dc:description>Etat de collection : 19 déc. 1903 [I, n° 1] jusqu'à la fin, 1909, 1912, 1917-1919, inc.</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32798129n/date</dc:identifier>
#                     <dc:identifier>ISSN 21304521</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Saint-Lô)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32798129n</dc:relation>
#                     <dc:relation>Première de couverture : 330119</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-85930</dc:source>
#                     <dc:title>Journal de la Manche et de la Basse-Normandie : Républicain progressiste, politique, littéraire, agricole, industriel et commercial, "puis" Républicain indépendant, politique, littéraire, agricole, industriel et commercial. Paraissant le mercredi et le samedi, "puis" le samedi</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>14</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32798129n/date</link>
#                 <nqamoyen>85.29</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k2353222p.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k2353222p</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1924-1944</dc:date>
#                     <dc:description>Périodicité : Hebdomadaire</dc:description>
#                     <dc:description>Etat de collection : 4 oct. 1924-20e année, n° 976 (26 mai 1944) &lt;inc.&gt;</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Rtmgus1</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : HNormand1</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32862901k/date</dc:identifier>
#                     <dc:identifier>ISSN 24975583</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Rouen)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32862901k</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-40288</dc:source>
#                     <dc:title>Rouen gazette</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>15</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32862901k/date</link>
#                 <nqamoyen>83.77</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k4521846m.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k4521846m</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:creator>France. Marine. Auteur du texte</dc:creator>
#                     <dc:date>1945</dc:date>
#                     <dc:description>Etat de collection : 1968-2010</dc:description>
#                     <dc:description>Numérisé par le partenaire</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb34348467k/date</dc:identifier>
#                     <dc:identifier>ISSN 00101834</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb34348467k</dc:relation>
#                     <dc:source>Marine nationale - Cols Bleus, 2015-66428</dc:source>
#                     <dc:title>Cols bleus (Paris)</dc:title>
#                     <dc:title>Cols bleus : hebdomadaire de la Marine française</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>16</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb34348467k/date</link>
#                 <nqamoyen>99.05</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k9785201c.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k9785201c</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:creator>Armée du Salut. Quartier général national (France). Auteur du texte</dc:creator>
#                     <dc:date>1882</dc:date>
#                     <dc:description>Variante(s) de titre : En avant et cri de guerre</dc:description>
#                     <dc:description>Variante(s) de titre : Le Vainqueur</dc:description>
#                     <dc:description>Variante(s) de titre : En avant : édition trimestrielle</dc:description>
#                     <dc:description>Périodicité : Hebdomadaire ; Trimestriel (2016-)</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb34493109k/date</dc:identifier>
#                     <dc:identifier>ISSN 12506702</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb34493109k</dc:relation>
#                     <dc:source>Fondation de l'Armée du Salut, 2019-3552</dc:source>
#                     <dc:title>En avant (Paris. 1882)</dc:title>
#                     <dc:title>En avant : bulletin hebdomadaire de l'Armée du Salut</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>17</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb34493109k/date</link>
#                 <nqamoyen>79.62</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k32050293.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k32050293</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Barbieux, Albert. Directeur de publication</dc:contributor>
#                     <dc:date>1869-1933</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo00</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo01</dc:description>
#                     <dc:description>Avec mode texte</dc:description>
#                     <dc:format>Nombre total de vues : 79956</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328479063/date</dc:identifier>
#                     <dc:identifier>ISSN 12575917</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328479063</dc:relation>
# ...
#                 <nqamoyen>74.9</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k3138589m.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k3138589m</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1904-1927</dc:date>
#                     <dc:description>Variante(s) de titre : Les Cévennes et le Midi</dc:description>
#                     <dc:description>Variante(s) de titre : Les Cévennes</dc:description>
#                     <dc:description>Périodicité : Mensuel ; hebdomadaire ; mensuel ; bi-mensuel ; irrégulier</dc:description>
#                     <dc:description>Etat de collection : avr. 1910-15 déc. 1923 (6e-23e année, n° 65-161). 31 mai 1924 (23e année, n° 163). 2 avr. 1927 (26e année, n° 167) jusqu'à la fin ; mq 1911 (n° 99), 1912 (n° 117, 122, 136)</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : LangRous1</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : 3M000</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb327391703/date</dc:identifier>
#                     <dc:identifier>ISSN 2123597X</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Alais)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb327391703</dc:relation>
#                     <dc:relation>Première de couverture : 212011</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-45308</dc:source>
#                     <dc:title>Les Cévennes sportives : journal de sport, industriel et de tourisme...</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>44</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb327391703/date</link>
#                 <nqamoyen>87.38</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k1035335s.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k1035335s</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Vaugeois, Henri (1864-1916). Directeur de publication</dc:contributor>
#                     <dc:contributor>Daudet, Léon (1867-1942). Directeur de publication</dc:contributor>
#                     <dc:contributor>Maurras, Charles (1868-1952). Directeur de publication</dc:contributor>
#                     <dc:creator>Action française. Auteur du texte</dc:creator>
#                     <dc:date>1908-1944</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Etat de collection : 1908-1941</dc:description>
#                     <dc:format>Nombre total de vues : 57453</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb326819451/date</dc:identifier>
#                     <dc:identifier>ISSN 09959599</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb326819451</dc:relation>
#                     <dc:relation>Première de couverture : 211970</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, GR FOL-LC2-6354</dc:source>
#                     <dc:title>L'Action française (Paris. 1908)</dc:title>
#                     <dc:title>L'Action française : organe du nationalisme intégral / directeur politique : Henri Vaugeois ; rédacteur en chef : Léon Daudet</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>45</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb326819451/date</link>
#                 <nqamoyen>71.58</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k757609t.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k757609t</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Couve, Benjamin (1844-1928). Éditeur scientifique</dc:contributor>
#                     <dc:contributor>Doumergue, Paul. Éditeur scientifique</dc:contributor>
#                     <dc:date>1898-2019</dc:date>
#                     <dc:description>Variante(s) de titre : Foi &amp; vie</dc:description>
#                     <dc:description>Variante(s) de titre : La Foi et la vie (Saint-Germain-en-Laye)</dc:description>
#                     <dc:description>Variante(s) de titre : Foi et vie. Cahier vert</dc:description>
#                     <dc:description>Variante(s) de titre : Foi et vie. Cahier A</dc:description>
#                     <dc:description>Variante(s) de titre : Foi et vie. Cahier biblique</dc:description>
#                     <dc:description>Variante(s) de titre : Foi et vie. Cahier d'études juives</dc:description>
#                     <dc:description>Variante(s) de titre : Foi et vie. Cahier d'études chrétiennes orientales</dc:description>
#                     <dc:description>Variante(s) de titre : Foi &amp; vie : revue de culture protestante</dc:description>
#                     <dc:description>Périodicité : Bi-hebd. puis bimens</dc:description>
#                     <dc:description>Etat de collection : 1899-1936</dc:description>
#                     <dc:description>Avec mode texte</dc:description>
#                     <dc:format>Nombre total de vues : 27488</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb327761001/date</dc:identifier>
#                     <dc:identifier>ISSN 00155357</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb327761001</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Philosophie, histoire, sciences de l'homme, 4-Z-1270</dc:source>
#                     <dc:title>Foi et vie (Paris)</dc:title>
#                     <dc:title>Foi et vie : revue de quinzaine, religieuse, morale, littéraire, sociale</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>46</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb327761001/date</link>
#                 <nqamoyen>96.91</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k5689944q.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k5689944q</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1900</dc:date>
#                     <dc:description>Variante(s) de titre : Les Nouvelles : journal quotidien d'Algérie</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328263310/date</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Alger)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328263310</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-87092</dc:source>
#                     <dc:title>Les Nouvelles (Alger)</dc:title>
#                     <dc:title>Les Nouvelles : journal quotidien du soir</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>47</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb328263310/date</link>
#                 <nqamoyen>77.83</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k5027989k.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k5027989k</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Schies, Julien (1875-1957). Directeur de publication</dc:contributor>
#                     <dc:date>1885-1939</dc:date>
#                     <dc:description>Variante(s) de titre : L'Alsacien (Strasbourg)</dc:description>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BNUStr017</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Alsace1</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BNUStr000</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BNUStr014</dc:description>
#                     <dc:format>Nombre total de vues : 7264</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb34396439w/date</dc:identifier>
#                     <dc:identifier>ISSN 0767774X</dc:identifier>
#                     <dc:language>ger</dc:language>
#                     <dc:publisher>[s.n.] (Strasbourg)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb34396439w</dc:relation>
#                     <dc:source>Bibliothèque nationale et universitaire de Strasbourg, M600057</dc:source>
#                     <dc:title>Der Elsässer</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>48</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb34396439w/date</link>
#                 <nqamoyen>74.5</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k3135919d.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k3135919d</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Girardin, Émile de (1806-1881). Directeur de publication</dc:contributor>
#                     <dc:contributor>Laguerre, Georges (1858-1912). Directeur de publication</dc:contributor>
#                     <dc:date>1836-1952</dc:date>
#                     <dc:description>Variante(s) de titre : La Presse universelle</dc:description>
#                     <dc:description>Variante(s) de titre : La Presse-Paysage</dc:description>
#                     <dc:description>Périodicité : Quotidien ; hebdomadaire (1937-1952)</dc:description>
#                     <dc:description>Etat de collection : 1836-</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pam1</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCFeTra</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCGen1</dc:description>
#                     <dc:format>Nombre total de vues : 124274</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb34448033b/date</dc:identifier>
#                     <dc:identifier>ISSN 11607718</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb34448033b</dc:relation>
#                     <dc:source>Bibliothèque nationale de France</dc:source>
#                     <dc:title>La Presse (Paris. 1836)</dc:title>
#                     <dc:title>La Presse</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>49</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb34448033b/date</link>
#                 <nqamoyen>99.04</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k5970898.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k5970898</uri>
#             </srw:extraRecordData>
#         </srw:record>
#     </srw:records>
#     <srw:nextRecordPosition>51</srw:nextRecordPosition>
# </srw:searchRetrieveResponse>

# %% [markdown]
# <b>Résultat</b> : 6687 documents de tout type (information donnée dans l'élément XML <srw:numberOfRecords>)

# %% [markdown]
# ### Utiliser le service de facettes pour obtenir la répartition des documents résultats selon leurs types

# %%
# création listes : types de documents et nombre
documents_types = []
documents_nb = []

# la requête de facettage  
req_url = "".join([CATEGORIEURL, 'gallica%20all%20%22titanic%22'])
print ("... appel de l'API Gallica Categories : ",req_url)
r = requests.get(req_url)
print (r.status_code)

# parser la réponse JSON pour en extraire les types de documents
json_4img = r.json()
for j in json_4img:   
    if j.get('value') == 'typedoc':
        documents_types.append(j.get('cleanValue'))
        documents_nb.append(j.get('howMany'))
print(documents_types)  
print(documents_nb)
# Out:
# ... appel de l'API Gallica Categories :  https://gallica.bnf.fr/services/Categories?SRU=gallica%20all%20%22titanic%22
# 200
# ['monographies', 'periodiques', 'images', 'sonores', 'partitions', 'manuscrits', 'cartes', 'videos']
# [4460, 2311, 20, 20, 19, 5, 1, 1]

# %% [markdown]
# <b>Résultat : </b> Flux JSON avec les facettes. Les valeurs par types de document sont donnés par la clé "typedoc".

# %% [markdown]
# #### a. Construire un graphe de la répartition des types de documents

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#création d'un dataframe des deux listes 
mydf = pd.DataFrame(list(zip(documents_nb, documents_types)), columns = ['Nombres de documents', 'Types de documents'])

# graphe
plt.figure(1, figsize = (16,8))
plt.bar(documents_types,documents_nb)
plt.ylabel('Nombre de documents')
plt.xlabel('Types de documents')
plt.xticks(fontsize=15)
plt.grid(True)

# %% [markdown]
# #### b. Construire un graphique en secteurs de la répartition des types de documents

# %%
import matplotlib.pyplot as plt

# dans cet exemple, étant donné leurs distrubutions, des catégories ont été regroupées
# définition des catégories
activities = ['monographies', 'périodiques', 'autres']
  
# valeurs des catégories
slices = [4471,2311,66]
  
# couleurs des catégories
colors = ['r', 'g', 'y',]
  
# construction du graphe
plt.pie(slices, labels = activities, colors=colors, startangle=90, shadow = True, radius = 4, autopct = '%1.1f%%')
plt.axis('equal')
plt.legend()

# affichage du graphe 
plt.show()

# %% [markdown]
# ### 2. Requête avancée n° 1 :

# %% [markdown]
# *   mot-clé = "titanic"
# *   type de document = presse et revues
# *   dates de publication = 15/04/1912 au 16/04/1912

# %%
req_url = "".join([BASEURL, '(text%20all%20"titanic"%20%20and%20(dc.type%20all%20"fascicule")%20and%20(gallicapublication_date>="1912/04/15"%20and%20gallicapublication_date<="1912/04/16")&exactSearch=false&collapsing=true'])

print ("... appel de l'API Gallica SRU : ",req_url)
r = requests.get(req_url)
print (r.text)
# Out:
# ... appel de l'API Gallica SRU :  https://gallica.bnf.fr/SRU?version=1.2&operation=searchRetrieve&maximumRecords=50&query=(text%20all%20"titanic"%20%20and%20(dc.type%20all%20"fascicule")%20and%20(gallicapublication_date>="1912/04/15"%20and%20gallicapublication_date<="1912/04/16")&exactSearch=false&collapsing=true
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <srw:searchRetrieveResponse xmlns:ns5="http://gallica.bnf.fr/namespaces/gallica/" xmlns:oai_dc="http://www.openarchives.org/OAI/2.0/oai_dc/" xmlns:srw="http://www.loc.gov/zing/srw/" xmlns:dc="http://purl.org/dc/elements/1.1/">
#     <srw:version>1.2</srw:version>
#     <srw:echoedSearchRetrieveRequest>
#         <srw:query>(text all "titanic"  and (dc.type all "fascicule") and (gallicapublication_date&gt;="1912/04/15" and gallicapublication_date&lt;="1912/04/16")</srw:query>
#         <srw:version>1.2</srw:version>
#     </srw:echoedSearchRetrieveRequest>
#     <srw:numberOfRecords>74</srw:numberOfRecords>
#     <srw:extraResponseData>&lt;numberOfRecordsDecollapser&gt;81&lt;/numberOfRecordsDecollapser&gt;</srw:extraResponseData>
#     <srw:records>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:creator>Parti social français. Auteur du texte</dc:creator>
#                     <dc:date>1863-1944</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Etat de collection : N° 1 (01/01/1863)-n° 29616 (27/08/1944)</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCFeTra</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCGen1</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo00</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo01</dc:description>
#                     <dc:format>Nombre total de vues : 146118</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32895690j/date</dc:identifier>
#                     <dc:identifier>ISSN 12560464</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:publisher>[s.n.] (Clermont-Ferrand)</dc:publisher>
#                     <dc:publisher>[s.n.] (Pau)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32895690j</dc:relation>
#                     <dc:relation>Première de couverture : 199685</dc:relation>
#                     <dc:source>Bibliothèque nationale de France</dc:source>
#                     <dc:title>Le Petit journal (Paris. 1863)</dc:title>
#                     <dc:title>Le Petit journal</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>0</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32895690j/date</link>
#                 <nqamoyen>77.19</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k619692n.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k619692n</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1906-1914</dc:date>
#                     <dc:description>Etat de collection : 1906-1914</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32806487g/date</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.?] (Oran)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32806487g</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-86393</dc:source>
#                     <dc:title>Le Libéral. Républicain indépendant</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>1</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32806487g/date</link>
#                 <nqamoyen>83.55</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k5069893v.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k5069893v</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Renaudin, Émile (1881-1968). Directeur de publication</dc:contributor>
#                     <dc:date>1902-1939</dc:date>
#                     <dc:description>Périodicité : Parait 3 fois par semaine</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32837115n/date</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Oran)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32837115n</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-87832</dc:source>
#                     <dc:title>Le Petit Oranais : petit africain, colon oranais : journal politique, littéraire, mondain, sportif, agricole, commercial et maritime</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>2</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32837115n/date</link>
#                 <nqamoyen>82.61</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k50099338.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k50099338</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Edwards, Alfred (1856-1914). Directeur de publication</dc:contributor>
#                     <dc:date>1884-1944</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Etat de collection : N° 1 (1884/02-26)-</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCFeTra</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCGen1</dc:description>
#                     <dc:format>Nombre total de vues : 123753</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328123058/date</dc:identifier>
#                     <dc:identifier>ISSN 12560359</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328123058</dc:relation>
#                     <dc:source>Bibliothèque nationale de France</dc:source>
#                     <dc:title>Le Matin (Paris. 1884)</dc:title>
#                     <dc:title>Le Matin : derniers télégrammes de la nuit</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>3</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb328123058/date</link>
#                 <nqamoyen>99.52</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k570128q.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k570128q</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:creator>Union républicaine (France). Auteur du texte</dc:creator>
#                     <dc:date>1886-1944</dc:date>
#                     <dc:description>Variante(s) de titre : La Dépêche de Brest et de l'Ouest</dc:description>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GMBrst001</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32755951g/date</dc:identifier>
#                     <dc:identifier>ISSN 21257531</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Brest)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32755951g</dc:relation>
#                     <dc:relation>Première de couverture : 236085</dc:relation>
#                     <dc:source>Bibliothèque municipale de Brest, PB A100</dc:source>
#                     <dc:title>La Dépêche de Brest : journal politique et maritime ["puis" journal de l'Union républicaine "puis" journal républicain quotidien "puis" quotidien républicain du matin]...</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>4</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32755951g/date</link>
#                 <nqamoyen>98.91</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k338339w.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k338339w</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Roujon, Jacques (1884-1971). Directeur de publication</dc:contributor>
#                     <dc:date>1876-1944</dc:date>
#                     <dc:description>Etat de collection : N1 (1876/10/15)-N4812 (1889/12/31)</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCFeTra</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCGen1</dc:description>
#                     <dc:format>Nombre total de vues : 126844</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb34419111x/date</dc:identifier>
#                     <dc:identifier>ISSN 09992707</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb34419111x</dc:relation>
#                     <dc:relation>Première de couverture : 201261</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, Gr Fol-Lc2-3850</dc:source>
#                     <dc:title>Le Petit Parisien (Paris)</dc:title>
#                     <dc:title>Le Petit Parisien : journal quotidien du soir</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>5</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb34419111x/date</link>
#                 <nqamoyen>99.45</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k564308h.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k564308h</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Pène, Henri de (1830-1888). Directeur de publication</dc:contributor>
#                     <dc:contributor>Tarbé des Sablons, Edmond Joseph Louis (1838-1900). Directeur de publication</dc:contributor>
#                     <dc:contributor>Meyer, Arthur (1844-1924). Directeur de publication</dc:contributor>
#                     <dc:date>1868-1929</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Etat de collection : 1868-1929</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pam1</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo00</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo01</dc:description>
#                     <dc:format>Nombre total de vues : 94503</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32779904b/date</dc:identifier>
#                     <dc:identifier>ISSN 11608404</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32779904b</dc:relation>
#                     <dc:source>Bibliothèque nationale de France</dc:source>
#                     <dc:title>Le Gaulois (Paris. 1868)</dc:title>
#                     <dc:title>Le Gaulois : littéraire et politique</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>6</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32779904b/date</link>
#                 <nqamoyen>99.55</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k535399j.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k535399j</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Girardin, Émile de (1806-1881). Directeur de publication</dc:contributor>
#                     <dc:contributor>Laguerre, Georges (1858-1912). Directeur de publication</dc:contributor>
#                     <dc:date>1836-1952</dc:date>
#                     <dc:description>Variante(s) de titre : La Presse universelle</dc:description>
#                     <dc:description>Variante(s) de titre : La Presse-Paysage</dc:description>
#                     <dc:description>Périodicité : Quotidien ; hebdomadaire (1937-1952)</dc:description>
#                     <dc:description>Etat de collection : 1836-</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pam1</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCFeTra</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCGen1</dc:description>
#                     <dc:format>Nombre total de vues : 124274</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb34448033b/date</dc:identifier>
#                     <dc:identifier>ISSN 11607718</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb34448033b</dc:relation>
#                     <dc:source>Bibliothèque nationale de France</dc:source>
#                     <dc:title>La Presse (Paris. 1836)</dc:title>
#                     <dc:title>La Presse</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>7</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb34448033b/date</link>
#                 <nqamoyen>99.15</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k597088w.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k597088w</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Rochefort, Henri (1831-1913). Directeur de publication</dc:contributor>
#                     <dc:date>1880-1948</dc:date>
#                     <dc:description>Variante(s) de titre : L'Intransigeant et le Journal de Paris</dc:description>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCFeTra</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCGen1</dc:description>
#                     <dc:format>Nombre total de vues : 118699</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32793876w/date</dc:identifier>
#                     <dc:identifier>ISSN 12560189</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32793876w</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, Gr Fol Lc2-3980</dc:source>
#                     <dc:title>L'Intransigeant (Paris. 1880)</dc:title>
#                     <dc:title>L'Intransigeant</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>8</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32793876w/date</link>
#                 <nqamoyen>72.03</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k786320m.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k786320m</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1912-1961</dc:date>
#                     <dc:description>Etat de collection : 16 mars 1912-1950</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : RfnEns0</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : RfnAfn1</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : RfnDHom1</dc:description>
#                     <dc:description>Avec mode texte</dc:description>
#                     <dc:format>Nombre total de vues : 67558</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb327596899/date</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Alger)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb327596899</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-10396</dc:source>
#                     <dc:title>L'Echo d'Alger : journal républicain du matin</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>9</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb327596899/date</link>
#                 <nqamoyen>99.64</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k75770793.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k75770793</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>De Waleffe, Maurice (1874-1946). Directeur de publication</dc:contributor>
#                     <dc:date>1911-1944</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32832672n/date</dc:identifier>
#                     <dc:identifier>ISSN 12560413</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32832672n</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-229</dc:source>
#                     <dc:title>Paris-midi : seul journal quotidien paraissant à midi / dir. Maurice de Waleffe</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>10</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32832672n/date</link>
#                 <nqamoyen>79.74</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k4719879p.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k4719879p</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Maret, Henry (1837-1917). Rédacteur</dc:contributor>
#                     <dc:contributor>Simond, Victor. Directeur de publication</dc:contributor>
#                     <dc:date>1881-1931</dc:date>
#                     <dc:description>Périodicité : Quotidien ; Hebdomadaire (15 août 1926-1931)</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32847124t/date</dc:identifier>
#                     <dc:identifier>ISSN 12576093</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32847124t</dc:relation>
#                     <dc:relation>Première de couverture : 201237</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-210</dc:source>
#                     <dc:title>Le Radical (Paris. 1881)</dc:title>
#                     <dc:title>Le Radical</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>11</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32847124t/date</link>
#                 <nqamoyen>98.5</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k7617524f.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k7617524f</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1829-1923</dc:date>
#                     <dc:description>Périodicité : Bihebdomadaire ou trihebdomadaire ; quotidien (9 mars 1848-6 mars 1852, 12 juin-31 oct. 1877, 9 mars 1880-30 juin 1923)</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : PrnS001</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328139024/date</dc:identifier>
#                     <dc:identifier>ISSN 12615919</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Pau)</dc:publisher>
#                     <dc:publisher>[s.n.][s.n.] (Pau)</dc:publisher>
#                     <dc:relation>Notice d'ensemble : http://catalogue.bnf.fr/ark:/12148/cb328139024</dc:relation>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328139024</dc:relation>
#                     <dc:relation>Première de couverture : 309697</dc:relation>
#                     <dc:source>Archives et bibliothèques Pau Béarn Pyrénées - Bibliothèque de Pau, Ee 1609</dc:source>
#                     <dc:title>Le Mémorial des Pyrénées : politique, judiciaire, industriel et d'annonces</dc:title>
#                     <dc:title>Le Mémorial des Pyrénées (Pau)</dc:title>
#                     <dc:title>Le Mémorial des Pyrénées : politique, judiciaire, industriel et d'annonces</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>12</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb328139024/date</link>
#                 <nqamoyen>81.72</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k5247355r.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k5247355r</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1856-1941</dc:date>
#                     <dc:description>Périodicité : Semi hebdomadaire ; trois fois par semaine ; semi hebdomadaire ; hebdomadaire</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32750594f/date</dc:identifier>
#                     <dc:identifier>ISSN 21247609</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (La Rochelle)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32750594f</dc:relation>
#                     <dc:relation>Première de couverture : 403359</dc:relation>
#                     <dc:source>Médiathèque Michel-Crépeau / La Rochelle, Per 6001</dc:source>
#                     <dc:title>Le Courrier de la Rochelle : journal politique, littéraire et d'annonces, feuille spéciale du commerce et de l'agriculture ["puis" journal républicain]</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>13</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32750594f/date</link>
#                 <nqamoyen>98.29</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k1146515j.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k1146515j</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Desgrées du Lou, Emmanuel (1867-1933). Directeur de publication</dc:contributor>
#                     <dc:date>1899-1944</dc:date>
#                     <dc:description>Variante(s) de titre : L'Ouest-Éclair et l'Étoile de mer</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Bretagn1</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GMBrst001</dc:description>
#                     <dc:format>Nombre total de vues : 135307</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32830550k/date</dc:identifier>
#                     <dc:identifier>ISSN 12616249</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Rennes)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32830550k</dc:relation>
#                     <dc:relation>Première de couverture : 212137</dc:relation>
#                     <dc:source>Bibliothèque nationale de France</dc:source>
#                     <dc:title>L'Ouest-Éclair (Rennes)</dc:title>
#                     <dc:title>L'Ouest-Éclair : journal quotidien d'informations, politique, littéraire, commercial</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>14</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32830550k/date</link>
#                 <nqamoyen>99.2</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k643232d.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k643232d</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Villemessant, Hippolyte de (1810-1879). Directeur de publication</dc:contributor>
#                     <dc:contributor>Jouvin, Benoît (1810-1886). Directeur de publication</dc:contributor>
#                     <dc:date>1854</dc:date>
#                     <dc:description>Variante(s) de titre : Le Figaro</dc:description>
#                     <dc:description>Périodicité : Hebdomadaire (1854-1855) ; deux fois par semaine (1856-11 novembre 1866) ; quotidien (16 novembre 1866-)</dc:description>
#                     <dc:description>Etat de collection : 1826 (1e janv.)-N° 365 (1935, 31 déc.)</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pam1</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo00</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo01</dc:description>
#                     <dc:format>Nombre total de vues : 164718</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb34355551z/date</dc:identifier>
#                     <dc:identifier>ISSN 01825852</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>Figaro (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb34355551z</dc:relation>
#                     <dc:source>Bibliothèque nationale de France</dc:source>
#                     <dc:title>Le Figaro (Paris. 1854)</dc:title>
#                     <dc:title>Figaro : journal non politique</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>15</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb34355551z/date</link>
#                 <nqamoyen>66.98</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k289554k.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k289554k</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1870-1944</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : RsAlis000</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : RsAlis013</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : RsAlis030</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb327558876/date</dc:identifier>
#                     <dc:identifier>ISSN 11556188</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Toulouse)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb327558876</dc:relation>
#                     <dc:relation>Première de couverture : 359370</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-10171</dc:source>
#                     <dc:title>La Dépêche (Toulouse)</dc:title>
#                     <dc:title>La Dépêche : journal quotidien</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>16</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb327558876/date</link>
#                 <nqamoyen>64.01</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k4141612q.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k4141612q</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>184?-1963</dc:date>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32759772v/date</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Oran)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32759772v</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-13582</dc:source>
#                     <dc:title>L'Écho d'Oran (Oran)</dc:title>
#                     <dc:title>L'Écho d'Oran : journal d'annonces légales, judiciaires, administratives et commerciales de la province d'Oran</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>17</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32759772v/date</link>
#                 <nqamoyen>67.69</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k67169323.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k67169323</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:creator>Groupe Bayard. Auteur du texte</dc:creator>
#                     <dc:date>1880-1968</dc:date>
#                     <dc:description>Périodicité : Mensuel (1880-juin 1883) ; Quotidien (16 juin 1883-1968)</dc:description>
#                     <dc:description>Etat de collection : T. 1, n° 1 (1880, avr.)-n° 3263 (1893, déc. 30)</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pam1</dc:description>
#                     <dc:description>Avec mode texte</dc:description>
#                     <dc:format>Nombre total de vues : 104176</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb343631418/date</dc:identifier>
#                     <dc:identifier>ISSN 02426412</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>La Croix (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb343631418</dc:relation>
#                     <dc:relation>Première de couverture : 201260</dc:relation>
#                     <dc:source>Bibliothèque nationale de France</dc:source>
#                     <dc:title>La Croix (1880)</dc:title>
#                     <dc:title>La Croix</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>18</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb343631418/date</link>
#                 <nqamoyen>99.49</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k258275q.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k258275q</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Muller, Charles. Directeur de publication</dc:contributor>
#                     <dc:contributor>Girardin, Émile de (1806-1881). Directeur de publication</dc:contributor>
#                     <dc:contributor>Détroyat, Léonce (1829-1898). Directeur de publication</dc:contributor>
#                     <dc:contributor>Berthoulat, Georges (1859-1930). Directeur de publication</dc:contributor>
#                     <dc:contributor>Aymard, Camille (1881-1964). Directeur de publication</dc:contributor>
#                     <dc:contributor>Ferry, Désiré (1886-1940). Directeur de publication</dc:contributor>
#                     <dc:contributor>Doriot, Jacques (1898-1945). Directeur de publication</dc:contributor>
#                     <dc:date>1865-1940</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo00</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo01</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328066631/date</dc:identifier>
#                     <dc:identifier>ISSN 12560286</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328066631</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-189</dc:source>
#                     <dc:title>La Liberté (Paris. 1865)</dc:title>
#                     <dc:title>La Liberté</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>19</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb328066631/date</link>
#                 <nqamoyen>61.2</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k4797735r.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k4797735r</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
# ...
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>43</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/la-democratie-issy-les-moulineaux/16-avril-1912/759/2161503</link>
#                 <nqamoyen>98.51</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k1737195p.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k1737195p</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Outrebon, Louis (18..-1884). Directeur de publication</dc:contributor>
#                     <dc:contributor>Vervoort, André (1865-1943). Directeur de publication</dc:contributor>
#                     <dc:date>1869-1932</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>BnF-partenariats, Presse Ancienne RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328705910/date</dc:identifier>
#                     <dc:identifier>ISSN 1257595X</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice d'ensemble : http://catalogue.bnf.fr/ark:/12148/cb328705910</dc:relation>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328705910</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Philosophie, histoire, sciences de l'homme, GR FOL-LC2-3209</dc:source>
#                     <dc:title>Le Soir : feuille de nouvelles ne paraissant qu'à sept heures et demie</dc:title>
#                     <dc:title>Le Soir (Paris. 1869)</dc:title>
#                     <dc:title>Le Soir : feuille de nouvelles ne paraissant qu'à sept heures et demie</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>44</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/le-soir/16-avril-1912/1199/3631557</link>
#                 <nqamoyen>92.0</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k25750269.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k25750269</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Millerand, Alexandre (1859-1943). Directeur de publication</dc:contributor>
#                     <dc:contributor>Guesde, Jules (1845-1922). Directeur de publication</dc:contributor>
#                     <dc:contributor>Gérault-Richard (1860-1911). Directeur de publication</dc:contributor>
#                     <dc:contributor>Dejean (Maurice ; 1861-1940). Directeur de publication</dc:contributor>
#                     <dc:contributor>Turot, Henri (1865-1922). Directeur de publication</dc:contributor>
#                     <dc:contributor>Puech, Louis (1852-1947). Directeur de publication</dc:contributor>
#                     <dc:date>1893-1938</dc:date>
#                     <dc:description>Variante(s) de titre : La Petite République socialiste</dc:description>
#                     <dc:description>Variante(s) de titre : La Petite République : socialiste</dc:description>
#                     <dc:description>Variante(s) de titre : La Petite République : artistique, littéraire, politique, sociale : nouvelles de tous, de tout, de partout</dc:description>
#                     <dc:description>Variante(s) de titre : La Petite République : journal de grande information, politique, littéraire</dc:description>
#                     <dc:description>Variante(s) de titre : La Petite République : politique, économique, littéraire</dc:description>
#                     <dc:description>Variante(s) de titre : La Petite République</dc:description>
#                     <dc:description>Périodicité : Quotidien ; irrégulier (1922-1938)</dc:description>
#                     <dc:description>BnF-partenariats, Presse Ancienne - RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb345185020/date</dc:identifier>
#                     <dc:identifier>ISSN 12576026</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb345185020</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, GR FOL-LC2-3816</dc:source>
#                     <dc:title>La Petite République (Paris)</dc:title>
#                     <dc:title>La Petite République : journal socialiste</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>45</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/la-petite-republique/16-avril-1912/667/1648345</link>
#                 <nqamoyen>98.51</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k49832105.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k49832105</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1868-1944</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>BnF-partenariats, Presse Ancienne - RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32836813n/date</dc:identifier>
#                     <dc:identifier>ISSN 12560472</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Marseille)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32836813n</dc:relation>
#                     <dc:relation>Première de couverture : 243213</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOB-19</dc:source>
#                     <dc:title>Le Petit Marseillais (1868)</dc:title>
#                     <dc:title>Le Petit Marseillais : journal quotidien ["puis" journal politique quotidien "puis" le plus important des journaux de province]</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>46</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/le-petit-marseillais/16-avril-1912/437/1604639</link>
#                 <nqamoyen>98.51</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k4910640t.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k4910640t</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1869-1944</dc:date>
#                     <dc:description>Périodicité : Hebdomadaire ; Quotidien</dc:description>
#                     <dc:description>BnF-partenariats, Presse Ancienne RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32844033s/date</dc:identifier>
#                     <dc:identifier>ISSN 27274373</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Amiens)</dc:publisher>
#                     <dc:relation>Notice d'ensemble : http://catalogue.bnf.fr/ark:/12148/cb32844033s</dc:relation>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32844033s</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-88366</dc:source>
#                     <dc:title>Le Progrès de la Somme : organe de la démocratie</dc:title>
#                     <dc:title>Le Progrès de la Somme : organe de la démocratie</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>47</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/le-progres-de-la-somme/16-avril-1912/2227/3786865</link>
#                 <nqamoyen>96.25</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k3595306b.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k3595306b</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Bérenger, Henry (1867-1952). Directeur de publication</dc:contributor>
#                     <dc:contributor>Parsons, Léon (1872-1941). Directeur de publication</dc:contributor>
#                     <dc:date>1903-1924</dc:date>
#                     <dc:description>Variante(s) de titre : L'Action quotidienne</dc:description>
#                     <dc:description>BnF-partenariats, Presse Ancienne RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb326821363/date</dc:identifier>
#                     <dc:identifier>ISSN 12559784</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb326821363</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Philosophie, histoire, sciences de l'homme, GR FOL-LC2-6143</dc:source>
#                     <dc:title>L'Action (Paris. 1903)</dc:title>
#                     <dc:title>L'Action : quotidienne, anticléricale, républicaine, socialiste</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>48</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/l-action/16-avril-1912/2095/3146721</link>
#                 <nqamoyen>88.33</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k2941048s.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k2941048s</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Gambetta, Léon (1838-1882). Directeur de publication</dc:contributor>
#                     <dc:date>1871-1924</dc:date>
#                     <dc:description>Variante(s) de titre : La République</dc:description>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>BnF-partenariats, Presse Ancienne - RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32853032d/date</dc:identifier>
#                     <dc:identifier>ISSN 12575933</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32853032d</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Philosophie, histoire, sciences de l'homme, GR FOL-LC2-3521</dc:source>
#                     <dc:title>La République française (Paris. 1871)</dc:title>
#                     <dc:title>La République française</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>49</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/la-republique-francaise/16-avril-1912/655/2667495</link>
#                 <nqamoyen>98.51</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k16005344.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k16005344</uri>
#             </srw:extraRecordData>
#         </srw:record>
#     </srw:records>
#     <srw:nextRecordPosition>51</srw:nextRecordPosition>
# </srw:searchRetrieveResponse>

# %% [markdown]
# <b>Résultat</b> : 73 périodiques

# %% [markdown]
# ### 3. Recherche avancée n° 2 : utilisation du critère de recherche par proximité

# %%
req_url = "".join([BASEURL, '((%20text%20all%20"astor"%20%20prox/unit=word/distance=10%20"titanic"))%20and%20(dc.type%20all%20"fascicule")%20and%20(gallicapublication_date>="1912/04/15"%20and%20gallicapublication_date<="1914/04/16")'])

print ("... appel de l'API Gallica SRU : ",req_url)
r = requests.get(req_url)
print (r.text)
# Out:
# ... appel de l'API Gallica SRU :  https://gallica.bnf.fr/SRU?version=1.2&operation=searchRetrieve&maximumRecords=50&query=((%20text%20all%20"astor"%20%20prox/unit=word/distance=10%20"titanic"))%20and%20(dc.type%20all%20"fascicule")%20and%20(gallicapublication_date>="1912/04/15"%20and%20gallicapublication_date<="1914/04/16")
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <srw:searchRetrieveResponse xmlns:ns5="http://gallica.bnf.fr/namespaces/gallica/" xmlns:oai_dc="http://www.openarchives.org/OAI/2.0/oai_dc/" xmlns:srw="http://www.loc.gov/zing/srw/" xmlns:dc="http://purl.org/dc/elements/1.1/">
#     <srw:version>1.2</srw:version>
#     <srw:echoedSearchRetrieveRequest>
#         <srw:query>(( text all "astor"  prox/unit=word/distance=10 "titanic")) and (dc.type all "fascicule") and (gallicapublication_date&gt;="1912/04/15" and gallicapublication_date&lt;="1914/04/16")</srw:query>
#         <srw:version>1.2</srw:version>
#     </srw:echoedSearchRetrieveRequest>
#     <srw:numberOfRecords>83</srw:numberOfRecords>
#     <srw:extraResponseData>&lt;numberOfRecordsDecollapser&gt;181&lt;/numberOfRecordsDecollapser&gt;</srw:extraResponseData>
#     <srw:records>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Busschère, Henri de (1874-1937). Directeur de publication</dc:contributor>
#                     <dc:date>1901-1919</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328338028/date</dc:identifier>
#                     <dc:identifier>ISSN 24295914</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Saint-Denis)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328338028</dc:relation>
#                     <dc:relation>Première de couverture : 387905</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-8256</dc:source>
#                     <dc:title>La Patrie créole : organe des intérêts généraux de l'île de La Réunion</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>0</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb328338028/date</link>
#                 <nqamoyen>86.98</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k50399793.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k50399793</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Chadeuil, Gustave (1821-1896). Directeur de publication</dc:contributor>
#                     <dc:date>1871-1921</dc:date>
#                     <dc:description>Variante(s) de titre : Le Dix-neuvième siècle (Paris. 1871)</dc:description>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Avec mode texte</dc:description>
#                     <dc:format>Nombre total de vues : 68249</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32757974m/date</dc:identifier>
#                     <dc:identifier>ISSN 17752949</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32757974m</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-199</dc:source>
#                     <dc:title>Le XIXe siècle (Paris. 1871)</dc:title>
#                     <dc:title>Le XIXe siècle : journal quotidien politique et littéraire / directeur-rédacteur en chef : Gustave Chadeuil</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>1</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32757974m/date</link>
#                 <nqamoyen>98.5</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k7569211j.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k7569211j</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Barbieux, Albert. Directeur de publication</dc:contributor>
#                     <dc:date>1869-1933</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo00</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo01</dc:description>
#                     <dc:description>Avec mode texte</dc:description>
#                     <dc:format>Nombre total de vues : 79956</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328479063/date</dc:identifier>
#                     <dc:identifier>ISSN 12575917</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328479063</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-43</dc:source>
#                     <dc:title>Le Rappel (Paris. 1869)</dc:title>
#                     <dc:title>Le Rappel / directeur gérant Albert Barbieux</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>2</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb328479063/date</link>
#                 <nqamoyen>98.5</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k7548645v.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k7548645v</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Allais, Alphonse (1854-1905). Directeur de publication</dc:contributor>
#                     <dc:contributor>Bringer, Rodolphe (1869-1943). Directeur de publication</dc:contributor>
#                     <dc:contributor>Briquet, Paul (1884-1930). Directeur de publication</dc:contributor>
#                     <dc:date>1899-1940</dc:date>
#                     <dc:description>Variante(s) de titre : Le Sourire de France</dc:description>
#                     <dc:description>Périodicité : ; Hebdomadaire ; bimensuel (?-mai 1940)</dc:description>
#                     <dc:description>Etat de collection : a. 12, n° 1 (1910, 1er janv. )-a. 16, n° 27 (1914, 2 juil.) ; a. 29 (1926) ; a. 34 (1931)</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328711647/date</dc:identifier>
#                     <dc:identifier>ISSN 20223609</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328711647</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Littérature et art, FOL-Z-837</dc:source>
#                     <dc:title>Le Sourire (Paris. 1899)</dc:title>
#                     <dc:title>Le Sourire : journal humoristique hebdomadaire / Maurice Méry, directeur ; Alphonse Allais, rédacteur en chef</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>3</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb328711647/date</link>
#                 <nqamoyen>87.57</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k11700826.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k11700826</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>184?-1963</dc:date>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32759772v/date</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Oran)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32759772v</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-13582</dc:source>
#                     <dc:title>L'Écho d'Oran (Oran)</dc:title>
#                     <dc:title>L'Écho d'Oran : journal d'annonces légales, judiciaires, administratives et commerciales de la province d'Oran</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>4</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32759772v/date</link>
#                 <nqamoyen>66.01</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k6716933h.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k6716933h</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1883-1939</dc:date>
#                     <dc:description>Variante(s) de titre : Les Annales (Paris)</dc:description>
#                     <dc:description>Variante(s) de titre : Les Annales politiques et littéraires : revue universelle illustrée hebdomadaire</dc:description>
#                     <dc:description>Périodicité : Hebdomadaire ; Bimensuel</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pam1</dc:description>
#                     <dc:description>Avec mode texte</dc:description>
#                     <dc:format>Nombre total de vues : 42932</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb34429261z/date</dc:identifier>
#                     <dc:identifier>ISSN 11494034</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb34429261z</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Collections numérisées, 2009-34518</dc:source>
#                     <dc:title>Les Annales politiques et littéraires : revue populaire paraissant le dimanche / dir. Adolphe Brisson</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>5</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb34429261z/date</link>
#                 <nqamoyen>99.98</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k5791819b.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k5791819b</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:creator>Union républicaine (France). Auteur du texte</dc:creator>
#                     <dc:date>1886-1944</dc:date>
#                     <dc:description>Variante(s) de titre : La Dépêche de Brest et de l'Ouest</dc:description>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GMBrst001</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32755951g/date</dc:identifier>
#                     <dc:identifier>ISSN 21257531</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Brest)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32755951g</dc:relation>
#                     <dc:relation>Première de couverture : 236085</dc:relation>
#                     <dc:source>Bibliothèque municipale de Brest, PB A100</dc:source>
#                     <dc:title>La Dépêche de Brest : journal politique et maritime ["puis" journal de l'Union républicaine "puis" journal républicain quotidien "puis" quotidien républicain du matin]...</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>6</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32755951g/date</link>
#                 <nqamoyen>98.69</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k338462k.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k338462k</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1912-1961</dc:date>
#                     <dc:description>Etat de collection : 16 mars 1912-1950</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : RfnEns0</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : RfnAfn1</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : RfnDHom1</dc:description>
#                     <dc:description>Avec mode texte</dc:description>
#                     <dc:format>Nombre total de vues : 67558</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb327596899/date</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Alger)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb327596899</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-10396</dc:source>
#                     <dc:title>L'Echo d'Alger : journal républicain du matin</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>7</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb327596899/date</link>
#                 <nqamoyen>99.96</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k7577080r.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k7577080r</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Maret, Henry (1837-1917). Rédacteur</dc:contributor>
#                     <dc:contributor>Simond, Victor. Directeur de publication</dc:contributor>
#                     <dc:date>1881-1931</dc:date>
#                     <dc:description>Périodicité : Quotidien ; Hebdomadaire (15 août 1926-1931)</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32847124t/date</dc:identifier>
#                     <dc:identifier>ISSN 12576093</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32847124t</dc:relation>
#                     <dc:relation>Première de couverture : 201237</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-210</dc:source>
#                     <dc:title>Le Radical (Paris. 1881)</dc:title>
#                     <dc:title>Le Radical</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>8</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32847124t/date</link>
#                 <nqamoyen>98.5</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k76158258.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k76158258</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1902-1920</dc:date>
#                     <dc:description>Etat de collection : 1re année, n° 1 (2 févr. 1902)-18 année, n° 809 (21 mars 1920) &lt;inc.&gt; &lt;éd. spéciale du 27 avr. 1914&gt; &lt;n° 2, 6, 8-10, 12-15 (6, 10, 12-14, 16-19 août 1914), éd. spéciale quotidienne&gt;</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32852208v/date</dc:identifier>
#                     <dc:identifier>ISSN 21030839</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Ruffec)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32852208v</dc:relation>
#                     <dc:relation>Première de couverture : 403404</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-89133</dc:source>
#                     <dc:title>Le Républicain (Ruffec)</dc:title>
#                     <dc:title>Le Républicain : organe hebdomadaire de la défense républicaine et des intérêts généraux de l'arrondissement de Ruffec ["puis" journal hebdomadaire, agricole, commercial, industriel, littéraire et politique, organe attitré des comités républicains de l'arrondissement de Ruffec "puis" journal hebdomadaire, organe de la démocratie ouvrière et paysanne des Charentes et du Poitou]</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>9</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32852208v/date</link>
#                 <nqamoyen>88.05</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k3271227n.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k3271227n</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1906-1914</dc:date>
#                     <dc:description>Etat de collection : 1906-1914</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32806487g/date</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.?] (Oran)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32806487g</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-86393</dc:source>
#                     <dc:title>Le Libéral. Républicain indépendant</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>10</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32806487g/date</link>
#                 <nqamoyen>81.87</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k5069934b.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k5069934b</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>De Waleffe, Maurice (1874-1946). Directeur de publication</dc:contributor>
#                     <dc:date>1911-1944</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32832672n/date</dc:identifier>
#                     <dc:identifier>ISSN 12560413</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32832672n</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-229</dc:source>
#                     <dc:title>Paris-midi : seul journal quotidien paraissant à midi / dir. Maurice de Waleffe</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>11</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32832672n/date</link>
#                 <nqamoyen>78.36</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k4719885d.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k4719885d</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Nefftzer, Auguste (1820-1876). Fondateur de la publication. Directeur de publication</dc:contributor>
#                     <dc:contributor>Hébrard, Adrien (1833-1914). Directeur de publication</dc:contributor>
#                     <dc:date>1861-1942</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Etat de collection : N° 1 (25 avr. 1861)-n° 27147 (31 déc. 1935)</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : FranceJp0</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo00</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo01</dc:description>
#                     <dc:description>Avec mode texte</dc:description>
#                     <dc:format>Nombre total de vues : 137484</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb34431794k/date</dc:identifier>
#                     <dc:identifier>ISSN 11501073</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb34431794k</dc:relation>
#                     <dc:relation>Première de couverture : 199686</dc:relation>
#                     <dc:source>Bibliothèque nationale de France</dc:source>
#                     <dc:title>Le Temps (Paris. 1861)</dc:title>
#                     <dc:title>Le Temps</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>12</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb34431794k/date</link>
#                 <nqamoyen>82.76</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k240948j.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k240948j</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Muller, Charles. Directeur de publication</dc:contributor>
#                     <dc:contributor>Girardin, Émile de (1806-1881). Directeur de publication</dc:contributor>
#                     <dc:contributor>Détroyat, Léonce (1829-1898). Directeur de publication</dc:contributor>
#                     <dc:contributor>Berthoulat, Georges (1859-1930). Directeur de publication</dc:contributor>
#                     <dc:contributor>Aymard, Camille (1881-1964). Directeur de publication</dc:contributor>
#                     <dc:contributor>Ferry, Désiré (1886-1940). Directeur de publication</dc:contributor>
#                     <dc:contributor>Doriot, Jacques (1898-1945). Directeur de publication</dc:contributor>
#                     <dc:date>1865-1940</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo00</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : BnPlCo01</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328066631/date</dc:identifier>
#                     <dc:identifier>ISSN 12560286</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328066631</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-189</dc:source>
#                     <dc:title>La Liberté (Paris. 1865)</dc:title>
#                     <dc:title>La Liberté</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>13</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb328066631/date</link>
#                 <nqamoyen>63.12</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k47977365.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k47977365</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:creator>Groupe Bayard. Auteur du texte</dc:creator>
#                     <dc:date>1880-1968</dc:date>
#                     <dc:description>Périodicité : Mensuel (1880-juin 1883) ; Quotidien (16 juin 1883-1968)</dc:description>
#                     <dc:description>Etat de collection : T. 1, n° 1 (1880, avr.)-n° 3263 (1893, déc. 30)</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : Pam1</dc:description>
#                     <dc:description>Avec mode texte</dc:description>
#                     <dc:format>Nombre total de vues : 104176</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb343631418/date</dc:identifier>
#                     <dc:identifier>ISSN 02426412</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>La Croix (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb343631418</dc:relation>
#                     <dc:relation>Première de couverture : 201260</dc:relation>
#                     <dc:source>Bibliothèque nationale de France</dc:source>
#                     <dc:title>La Croix (1880)</dc:title>
#                     <dc:title>La Croix</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>14</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb343631418/date</link>
#                 <nqamoyen>99.52</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k2582797.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k2582797</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1901-1914</dc:date>
#                     <dc:description>Périodicité : Trihebdomadaireparaît le mardi, le jeudi, le samedi et le dimanche</dc:description>
#                     <dc:description>Etat de collection : 1901-1914</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32854011p/date</dc:identifier>
#                     <dc:identifier>ISSN 22645691</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Chauny)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32854011p</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-89436</dc:source>
#                     <dc:title>Le Réveil de l'Aisne : journal républicain libéral</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>15</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32854011p/date</link>
#                 <nqamoyen>86.88</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k5120729p.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k5120729p</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Lafitte, Pierre (1872-1938). Directeur de publication</dc:contributor>
#                     <dc:date>1910-1943</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32771891w/date</dc:identifier>
#                     <dc:identifier>ISSN 12559997</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32771891w</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-228</dc:source>
#                     <dc:title>Excelsior (Paris. 1910)</dc:title>
#                     <dc:title>Excelsior : journal illustré quotidien : informations, littérature, sciences, arts, sports, théâtre, élégances</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>16</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32771891w/date</link>
#                 <nqamoyen>83.68</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k4601692v.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k4601692v</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Edwards, Alfred (1856-1914). Directeur de publication</dc:contributor>
#                     <dc:date>1884-1944</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Etat de collection : N° 1 (1884/02-26)-</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCFeTra</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : GCGen1</dc:description>
#                     <dc:format>Nombre total de vues : 123753</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328123058/date</dc:identifier>
#                     <dc:identifier>ISSN 12560359</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328123058</dc:relation>
#                     <dc:source>Bibliothèque nationale de France</dc:source>
#                     <dc:title>Le Matin (Paris. 1884)</dc:title>
#                     <dc:title>Le Matin : derniers télégrammes de la nuit</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>17</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb328123058/date</link>
#                 <nqamoyen>99.37</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k570152g.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k570152g</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1890-1944</dc:date>
#                     <dc:description>Variante(s) de titre : A partir de [...] paraît en plusieurs éd. locales. - Remplace l'éd. du matin à 5 centimes de : "Echo (L') du Nord. Journal politique..." - Du 18 mai au 31 juil. 1940 [?] remplacé par : "Gazette du Nord. Bulletin quotidien d'informations". - D'août au 31 déc. 1940 l'éd. de Roubaix [?] absorbe : "Journal de Roubaix" et paraît sous le titre de : "Grand écho du Nord et journal de Roubaix"</dc:description>
#                     <dc:description>Variante(s) de titre : Le Grand écho du Nord et du Pas-de-Calais</dc:description>
#                     <dc:description>Variante(s) de titre : Grand écho du Nord et journal de Roubaix</dc:description>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Etat de collection : Jusqu'à : 27 sept. 1914 (96e année, n° 270), 16 févr. 1919 (101e année, n° 47) jusqu'à la fin, inc. ; 4 mars 1923-1944, dernière éd. de Lille</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : NordPdeC1</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32783482h/date</dc:identifier>
#                     <dc:identifier>ISSN 20169175</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:language>français</dc:language>
#                     <dc:publisher> (Lille)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32783482h</dc:relation>
#                     <dc:relation>Première de couverture : 450011</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-85088</dc:source>
#                     <dc:title>Le Grand écho du Nord de la France</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>18</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32783482h/date</link>
#                 <nqamoyen>77.26</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k4762479h.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k4762479h</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1870-1944</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : RsAlis000</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : RsAlis013</dc:description>
#                     <dc:description>Appartient à l’ensemble documentaire : RsAlis030</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb327558876/date</dc:identifier>
#                     <dc:identifier>ISSN 11556188</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Toulouse)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb327558876</dc:relation>
#                     <dc:relation>Première de couverture : 359370</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOD-10171</dc:source>
#                     <dc:title>La Dépêche (Toulouse)</dc:title>
#                     <dc:title>La Dépêche : journal quotidien</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>19</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb327558876/date</link>
#                 <nqamoyen>79.69</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k4146755c.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k4146755c</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Flachon, Victor. Directeur de publication</dc:contributor>
#                     <dc:date>1877-1938</dc:date>
#                     <dc:description>Avec mode texte</dc:description>
#                     <dc:format>Nombre total de vues : 86207</dc:format>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328051026/date</dc:identifier>
#                     <dc:identifier>ISSN 1256026X</dc:identifier>
# ...
#                     <dc:description>BnF-partenariats, Presse Ancienne RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb328222296/date</dc:identifier>
#                     <dc:identifier>ISSN 12615943</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328222296</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, GR FOL-LC2-4189</dc:source>
#                     <dc:title>La Nation (Paris. 1884)</dc:title>
#                     <dc:title>La Nation / directeur Camille Dreyfus ; rédacteur en chef Edmond Théry</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>43</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/la-nation/17-aout-1912/1149/3655621</link>
#                 <nqamoyen>92.0</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k2454639w.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k2454639w</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Genoude, Antoine-Eugène (1792-1849). Collaborateur</dc:contributor>
#                     <dc:contributor>Lourdoueix, Paul de (18..-1868). Directeur de publication</dc:contributor>
#                     <dc:date>1848-1915</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>BnF-partenariats, Presse Ancienne - RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32780296x/date</dc:identifier>
#                     <dc:identifier>ISSN 19586779</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32780296x</dc:relation>
#                     <dc:relation>Première de couverture : 236168</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, 4-LC2-1</dc:source>
#                     <dc:title>La Gazette de France (1848)</dc:title>
#                     <dc:title>La Gazette de France</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>44</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/la-gazette-de-france/20-avril-1912/379/1471697</link>
#                 <nqamoyen>98.51</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k4845222n.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k4845222n</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1875-1941</dc:date>
#                     <dc:description>BnF-partenariats, Presse Ancienne - RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32763125f/date</dc:identifier>
#                     <dc:identifier>ISSN 21267790</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Saint-Jean-d'Angely)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32763125f</dc:relation>
#                     <dc:relation>Première de couverture : 243130</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JO-14086</dc:source>
#                     <dc:title>L'Écho saintongeais : Journal littéraire, agricole, commercial et d'annonces</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>45</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/l-echo-saintongeais/05-mai-1912/665/1843315</link>
#                 <nqamoyen>98.51</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k4960747f.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k4960747f</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1868-1921</dc:date>
#                     <dc:description>Périodicité : Quotidien</dc:description>
#                     <dc:description>BnF-partenariats, Presse Ancienne - RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32789920s/date</dc:identifier>
#                     <dc:identifier>ISSN 2129660X</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Reims)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32789920s</dc:relation>
#                     <dc:relation>Première de couverture : 303772</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, 8-LC22-756</dc:source>
#                     <dc:title>L'Indépendant rémois : journal quotidien : politique, commercial, économique et littéraire</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>46</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://gallica.bnf.fr/ark:/12148/cb32789920s/date</link>
#                 <nqamoyen>98.51</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k1781379s.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k1781379s</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:contributor>Millerand, Alexandre (1859-1943). Directeur de publication</dc:contributor>
#                     <dc:contributor>Guesde, Jules (1845-1922). Directeur de publication</dc:contributor>
#                     <dc:contributor>Gérault-Richard (1860-1911). Directeur de publication</dc:contributor>
#                     <dc:contributor>Dejean (Maurice ; 1861-1940). Directeur de publication</dc:contributor>
#                     <dc:contributor>Turot, Henri (1865-1922). Directeur de publication</dc:contributor>
#                     <dc:contributor>Puech, Louis (1852-1947). Directeur de publication</dc:contributor>
#                     <dc:date>1893-1938</dc:date>
#                     <dc:description>Variante(s) de titre : La Petite République socialiste</dc:description>
#                     <dc:description>Variante(s) de titre : La Petite République : socialiste</dc:description>
#                     <dc:description>Variante(s) de titre : La Petite République : artistique, littéraire, politique, sociale : nouvelles de tous, de tout, de partout</dc:description>
#                     <dc:description>Variante(s) de titre : La Petite République : journal de grande information, politique, littéraire</dc:description>
#                     <dc:description>Variante(s) de titre : La Petite République : politique, économique, littéraire</dc:description>
#                     <dc:description>Variante(s) de titre : La Petite République</dc:description>
#                     <dc:description>Périodicité : Quotidien ; irrégulier (1922-1938)</dc:description>
#                     <dc:description>BnF-partenariats, Presse Ancienne - RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb345185020/date</dc:identifier>
#                     <dc:identifier>ISSN 12576026</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher>[s.n.] (Paris)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb345185020</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, GR FOL-LC2-3816</dc:source>
#                     <dc:title>La Petite République (Paris)</dc:title>
#                     <dc:title>La Petite République : journal socialiste</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>47</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/la-petite-republique/16-aout-1912/667/2679481</link>
#                 <nqamoyen>98.51</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k49833323.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k49833323</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1880-1944</dc:date>
#                     <dc:description>Etat de collection : 1926</dc:description>
#                     <dc:description>BnF-partenariats, Presse Ancienne RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32837257v/date</dc:identifier>
#                     <dc:identifier>ISSN 12575984</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Marseille)</dc:publisher>
#                     <dc:relation>Notice d'ensemble : http://catalogue.bnf.fr/ark:/12148/cb32837257v</dc:relation>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32837257v</dc:relation>
#                     <dc:relation>Première de couverture : 277000</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOB-21</dc:source>
#                     <dc:title>Le Petit Provençal : journal politique quotidien</dc:title>
#                     <dc:title>Le Petit Provençal : journal politique quotidien</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>48</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/le-petit-provencal/17-avril-1912/677/3161725</link>
#                 <nqamoyen>93.5</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k2747870r.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k2747870r</uri>
#             </srw:extraRecordData>
#         </srw:record>
#         <srw:record>
#             <srw:recordSchema>http://www.openarchives.org/OAI/2.0/OAIdc.xsd</srw:recordSchema>
#             <srw:recordPacking>xml</srw:recordPacking>
#             <srw:recordData>
#                 <oai_dc:dc>
#                     <dc:date>1877-1914</dc:date>
#                     <dc:description>BnF-partenariats, Presse Ancienne RetroNews</dc:description>
#                     <dc:identifier>https://gallica.bnf.fr/ark:/12148/cb32772298w/date</dc:identifier>
#                     <dc:identifier>ISSN 20153961</dc:identifier>
#                     <dc:language>fre</dc:language>
#                     <dc:publisher> (Mulhouse)</dc:publisher>
#                     <dc:relation>Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb32772298w</dc:relation>
#                     <dc:source>Bibliothèque nationale de France, département Droit, économie, politique, JOB-28</dc:source>
#                     <dc:title>Express (Mulhouse)</dc:title>
#                     <dc:title>Express : journal politique paraissant à Mulhouse</dc:title>
#                     <dc:title>Express : Politische Zeitung erschinend in Mülhausen</dc:title>
#                     <dc:title>Express : Mülhauser Zeitung</dc:title>
#                     <dc:type>text</dc:type>
#                     <dc:type>texte</dc:type>
#                     <dc:type>publication en série imprimée</dc:type>
#                     <dc:type>printed serial</dc:type>
#                 </oai_dc:dc>
#             </srw:recordData>
#             <srw:recordIdentifier>ark</srw:recordIdentifier>
#             <srw:recordPosition>49</srw:recordPosition>
#             <srw:extraRecordData>
#                 <epubFile></epubFile>
#                 <infoSupModifiable></infoSupModifiable>
#                 <link>https://www.retronews.fr/journal/express/22-avril-1912/1303/3479741</link>
#                 <nqamoyen>90.5</nqamoyen>
#                 <thumbnail>https://gallica.bnf.fr/ark:/12148/bpt6k2435028s.thumbnail</thumbnail>
#                 <typedoc>periodiques</typedoc>
#                 <uri>bpt6k2435028s</uri>
#             </srw:extraRecordData>
#         </srw:record>
#     </srw:records>
#     <srw:nextRecordPosition>51</srw:nextRecordPosition>
# </srw:searchRetrieveResponse>

# %% [markdown]
# <b>Résultat</b> : 79 titres de périodique

# %% [markdown]
# #### Parser le contenu XML de la réponse SRU pour en extraire les réponses

# %%
from bs4 import BeautifulSoup as bs
bs_content = bs(r.text, "lxml")

# Extraire les identifiants de chaque document, stockés dans un élément <dc:identifier>
for ark in bs_content.find_all("dc:identifier"):
    print(ark.get_text())
# Out:
# https://gallica.bnf.fr/ark:/12148/cb328338028/date
# ISSN 24295914
# https://gallica.bnf.fr/ark:/12148/cb32757974m/date
# ISSN 17752949
# https://gallica.bnf.fr/ark:/12148/cb328479063/date
# ISSN 12575917
# https://gallica.bnf.fr/ark:/12148/cb328711647/date
# ISSN 20223609
# https://gallica.bnf.fr/ark:/12148/cb32759772v/date
# https://gallica.bnf.fr/ark:/12148/cb34429261z/date
# ISSN 11494034
# https://gallica.bnf.fr/ark:/12148/cb32755951g/date
# ISSN 21257531
# https://gallica.bnf.fr/ark:/12148/cb327596899/date
# https://gallica.bnf.fr/ark:/12148/cb32847124t/date
# ISSN 12576093
# https://gallica.bnf.fr/ark:/12148/cb32852208v/date
# ISSN 21030839
# https://gallica.bnf.fr/ark:/12148/cb32806487g/date
# https://gallica.bnf.fr/ark:/12148/cb32832672n/date
# ISSN 12560413
# https://gallica.bnf.fr/ark:/12148/cb34431794k/date
# ISSN 11501073
# https://gallica.bnf.fr/ark:/12148/cb328066631/date
# ISSN 12560286
# https://gallica.bnf.fr/ark:/12148/cb343631418/date
# ISSN 02426412
# https://gallica.bnf.fr/ark:/12148/cb32854011p/date
# ISSN 22645691
# https://gallica.bnf.fr/ark:/12148/cb32771891w/date
# ISSN 12559997
# https://gallica.bnf.fr/ark:/12148/cb328123058/date
# ISSN 12560359
# https://gallica.bnf.fr/ark:/12148/cb32783482h/date
# ISSN 20169175
# https://gallica.bnf.fr/ark:/12148/cb327558876/date
# ISSN 11556188
# https://gallica.bnf.fr/ark:/12148/cb328051026/date
# ISSN 1256026X
# https://gallica.bnf.fr/ark:/12148/cb328225965/date
# ISSN 20208413
# https://gallica.bnf.fr/ark:/12148/cb327888866/date
# https://gallica.bnf.fr/ark:/12148/cb34520232c/date
# ISSN 12603813
# https://gallica.bnf.fr/ark:/12148/cb32740226x/date
# ISSN 12739324
# https://gallica.bnf.fr/ark:/12148/cb34448033b/date
# ISSN 11607718
# https://gallica.bnf.fr/ark:/12148/cb32837965d/date
# ISSN 25571931
# https://gallica.bnf.fr/ark:/12148/cb32760004g/date
# ISSN 21078572
# https://gallica.bnf.fr/ark:/12148/cb34419111x/date
# ISSN 09992707
# https://gallica.bnf.fr/ark:/12148/cb34473289x/date
# ISSN 12465666
# https://gallica.bnf.fr/ark:/12148/cb32714693h/date
# ISSN 2493058X
# https://gallica.bnf.fr/ark:/12148/cb344298410/date
# ISSN 11499397
# https://gallica.bnf.fr/ark:/12148/cb32847920n/date
# https://gallica.bnf.fr/ark:/12148/cb32854997q/date
# https://gallica.bnf.fr/ark:/12148/cb328139024/date
# ISSN 12615919
# https://gallica.bnf.fr/ark:/12148/cb326819451/date
# ISSN 09959599
# https://gallica.bnf.fr/ark:/12148/cb32779904b/date
# ISSN 11608404
# https://gallica.bnf.fr/ark:/12148/cb32798129n/date
# ISSN 21304521
# https://gallica.bnf.fr/ark:/12148/cb32706846t/date
# ISSN 12559792
# https://gallica.bnf.fr/ark:/12148/cb34415871r/date
# ISSN 09962166
# https://gallica.bnf.fr/ark:/12148/cb32818319d/date
# ISSN 0996228X
# https://gallica.bnf.fr/ark:/12148/cb327513390/date
# ISSN 27265153
# https://gallica.bnf.fr/ark:/12148/cb32832124d/date
# ISSN 12560391
# https://gallica.bnf.fr/ark:/12148/cb328222296/date
# ISSN 12615943
# https://gallica.bnf.fr/ark:/12148/cb32780296x/date
# ISSN 19586779
# https://gallica.bnf.fr/ark:/12148/cb32763125f/date
# ISSN 21267790
# https://gallica.bnf.fr/ark:/12148/cb32789920s/date
# ISSN 2129660X
# https://gallica.bnf.fr/ark:/12148/cb345185020/date
# ISSN 12576026
# https://gallica.bnf.fr/ark:/12148/cb32837257v/date
# ISSN 12575984
# https://gallica.bnf.fr/ark:/12148/cb32772298w/date
# ISSN 20153961

# %% [markdown]
# <b>Résultat</b> : une liste d'identifiants de notice de périodique. Le comportement par défaut de Gallica est de renvoyer des titres de périodique et non des fascicules

# %% [markdown]
# #### Extraire les documents eux-mêmes : le paramètre collapsing=false permet d'obtenir les numéros des fascicules correspondant à la requête

# %%
req_url = "".join([BASEURL, '((%20text%20all%20"astor"%20%20prox/unit=word/distance=10%20"titanic"))%20and%20(dc.type%20all%20"fascicule")%20and%20(gallicapublication_date>="1912/04/15"%20and%20gallicapublication_date<="1914/04/16")&collapsing=false'])

print ("... appel de l'API Gallica SRU : ",req_url)
r = requests.get(req_url)
bs_content = bs(r.text, "lxml")
for record in bs_content.find_all("srw:record"):
    print(record.find("dc:title").get_text())
    print(record.find("dc:identifier").get_text())
# Out:
# ... appel de l'API Gallica SRU :  https://gallica.bnf.fr/SRU?version=1.2&operation=searchRetrieve&maximumRecords=50&query=((%20text%20all%20"astor"%20%20prox/unit=word/distance=10%20"titanic"))%20and%20(dc.type%20all%20"fascicule")%20and%20(gallicapublication_date>="1912/04/15"%20and%20gallicapublication_date<="1914/04/16")&collapsing=false
# La Patrie créole : organe des intérêts généraux de l'île de La Réunion
# https://gallica.bnf.fr/ark:/12148/bpt6k50399793
# Le XIXe siècle : journal quotidien politique et littéraire / directeur-rédacteur en chef : Gustave Chadeuil
# https://gallica.bnf.fr/ark:/12148/bpt6k7569211j
# Le Rappel / directeur gérant Albert Barbieux
# https://gallica.bnf.fr/ark:/12148/bpt6k7548645v
# Le Sourire : journal humoristique hebdomadaire / Maurice Méry, directeur ; Alphonse Allais, rédacteur en chef
# https://gallica.bnf.fr/ark:/12148/bpt6k11700826
# L'Écho d'Oran : journal d'annonces légales, judiciaires, administratives et commerciales de la province d'Oran
# https://gallica.bnf.fr/ark:/12148/bpt6k6716933h
# Les Annales politiques et littéraires : revue populaire paraissant le dimanche / dir. Adolphe Brisson
# https://gallica.bnf.fr/ark:/12148/bpt6k5791819b
# La Dépêche de Brest : journal politique et maritime ["puis" journal de l'Union républicaine "puis" journal républicain quotidien "puis" quotidien républicain du matin]...
# https://gallica.bnf.fr/ark:/12148/bpt6k338462k
# L'Echo d'Alger : journal républicain du matin
# https://gallica.bnf.fr/ark:/12148/bpt6k7577080r
# Le Radical
# https://gallica.bnf.fr/ark:/12148/bpt6k76158258
# Le Républicain : organe hebdomadaire de la défense républicaine et des intérêts généraux de l'arrondissement de Ruffec ["puis" journal hebdomadaire, agricole, commercial, industriel, littéraire et politique, organe attitré des comités républicains de l'arrondissement de Ruffec "puis" journal hebdomadaire, organe de la démocratie ouvrière et paysanne des Charentes et du Poitou]
# https://gallica.bnf.fr/ark:/12148/bpt6k3271227n
# Le Libéral. Républicain indépendant
# https://gallica.bnf.fr/ark:/12148/bpt6k5069934b
# Paris-midi : seul journal quotidien paraissant à midi / dir. Maurice de Waleffe
# https://gallica.bnf.fr/ark:/12148/bpt6k4719885d
# Le Temps
# https://gallica.bnf.fr/ark:/12148/bpt6k240948j
# Le Radical
# https://gallica.bnf.fr/ark:/12148/bpt6k76175498
# Le Temps
# https://gallica.bnf.fr/ark:/12148/bpt6k240851x
# La Liberté
# https://gallica.bnf.fr/ark:/12148/bpt6k47977365
# La Croix
# https://gallica.bnf.fr/ark:/12148/bpt6k2582797
# Le Réveil de l'Aisne : journal républicain libéral
# https://gallica.bnf.fr/ark:/12148/bpt6k5120729p
# L'Écho d'Oran : journal d'annonces légales, judiciaires, administratives et commerciales de la province d'Oran
# https://gallica.bnf.fr/ark:/12148/bpt6k67169390
# Excelsior : journal illustré quotidien : informations, littérature, sciences, arts, sports, théâtre, élégances
# https://gallica.bnf.fr/ark:/12148/bpt6k4601692v
# Le Matin : derniers télégrammes de la nuit
# https://gallica.bnf.fr/ark:/12148/bpt6k570152g
# Le Grand écho du Nord de la France
# https://gallica.bnf.fr/ark:/12148/bpt6k4762479h
# La Dépêche : journal quotidien
# https://gallica.bnf.fr/ark:/12148/bpt6k4146755c
# La Lanterne : journal politique quotidien
# https://gallica.bnf.fr/ark:/12148/bpt6k7514270g
# Navigazette
# https://gallica.bnf.fr/ark:/12148/bpt6k55230065
# L'Echo d'Alger : journal républicain du matin
# https://gallica.bnf.fr/ark:/12148/bpt6k75770830
# L'Impartial : organe républicain des intérêts de Djidjelli et de la région
# https://gallica.bnf.fr/ark:/12148/bpt6k57847150
# L'Univers
# https://gallica.bnf.fr/ark:/12148/bpt6k7150650
# La Charente
# https://gallica.bnf.fr/ark:/12148/bpt6k46419104
# La Charente
# https://gallica.bnf.fr/ark:/12148/bpt6k4641925k
# Le Grand écho du Nord de la France
# https://gallica.bnf.fr/ark:/12148/bpt6k47624820
# La Charente
# https://gallica.bnf.fr/ark:/12148/bpt6k4642119d
# Les Annales politiques et littéraires : revue populaire paraissant le dimanche / dir. Adolphe Brisson
# https://gallica.bnf.fr/ark:/12148/bpt6k57918163
# Le Grand écho du Nord de la France
# https://gallica.bnf.fr/ark:/12148/bpt6k47624805
# L'Écho d'Oran : journal d'annonces légales, judiciaires, administratives et commerciales de la province d'Oran
# https://gallica.bnf.fr/ark:/12148/bpt6k67174971
# L'Echo d'Alger : journal républicain du matin
# https://gallica.bnf.fr/ark:/12148/bpt6k75744391
# La Croix
# https://gallica.bnf.fr/ark:/12148/bpt6k2582805
# La Presse
# https://gallica.bnf.fr/ark:/12148/bpt6k5976593
# L'Écho d'Oran : journal d'annonces légales, judiciaires, administratives et commerciales de la province d'Oran
# https://gallica.bnf.fr/ark:/12148/bpt6k6716936r
# La Petite presse : journal quotidien... / [rédacteur en chef : Balathier Bragelonne]
# https://gallica.bnf.fr/ark:/12148/bpt6k4726907w
# L'Écho de Jarnac
# https://gallica.bnf.fr/ark:/12148/bpt6k2375662r
# Le Radical
# https://gallica.bnf.fr/ark:/12148/bpt6k7615824v
# La Presse
# https://gallica.bnf.fr/ark:/12148/bpt6k597088w
# Le Petit Parisien : journal quotidien du soir
# https://gallica.bnf.fr/ark:/12148/bpt6k564322x
# La Liberté
# https://gallica.bnf.fr/ark:/12148/bpt6k4797750f
# Paris-midi : seul journal quotidien paraissant à midi / dir. Maurice de Waleffe
# https://gallica.bnf.fr/ark:/12148/bpt6k4719883k
# Le Journal
# https://gallica.bnf.fr/ark:/12148/bpt6k76222563
# Le Bon temps
# https://gallica.bnf.fr/ark:/12148/bpt6k948202c
# L'Écho d'Oran : journal d'annonces légales, judiciaires, administratives et commerciales de la province d'Oran
# https://gallica.bnf.fr/ark:/12148/bpt6k6716940n
# Le XIXe siècle : journal quotidien politique et littéraire / directeur-rédacteur en chef : Gustave Chadeuil
# https://gallica.bnf.fr/ark:/12148/bpt6k75692104

# %% [markdown]
# <b>Résultat</b> : les 50 premiers titres et identifiants des numéros correspondant à la requête

# %% [markdown]
# ### 4. Obtenir le calendrier d'un périodique avec le service de récupération des années et fascicules parus. Exemple avec le premier numéro résultat de la recherche précédente : <i>La Patrie créole</i>

# %%
import datetime

# Obtenir le premier résultat de la liste des résultats
numero = bs_content.find("srw:record")
print(" titre : ", numero.find("dc:title").get_text())

# obtenir la date de publication du numéro pour en déduire l'année de publication
myDate = numero.find("dc:date").get_text()
print(" date : ", myDate)
dateObj = datetime.datetime.strptime(myDate, '%Y-%m-%d')

# obtenir l'identifiant de la notice catalogue du titre
print( " notice : ", numero.find("dc:relation").get_text())  

# Utiliser l'API Issue avec l'identifiant ark de la notice et l'année recherchée
ark = numero.find("dc:relation").get_text().split(".fr/")[1]
req_url = "".join([ISSUEURL, ark, '/date&date=', str(dateObj.year)])

print ("\n... appel de l'API Gallica Issue : ",req_url)
r = requests.get(req_url)
print (r.text)
# Out:
#  titre :  La Patrie créole : organe des intérêts généraux de l'île de La Réunion
#  date :  1912-06-20
#  notice :  Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb328338028
#
# ... appel de l'API Gallica Issue :  https://gallica.bnf.fr/services/Issues?ark=ark:/12148/cb328338028/date&date=1912
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <issues compile_time="0:00:11.351" date="1912" listType="issue" parentArk="ark:/12148/cb328338028/date">
# <issue ark="bpt6k5039919t" dayOfYear="2">02 janvier 1912</issue>
# <issue ark="bpt6k5039920g" dayOfYear="4">04 janvier 1912</issue>
# <issue ark="bpt6k5039921w" dayOfYear="5">05 janvier 1912</issue>
# <issue ark="bpt6k50399229" dayOfYear="6">06 janvier 1912</issue>
# <issue ark="bpt6k5039918d" dayOfYear="7">07 janvier 1912</issue>
# <issue ark="bpt6k5039923q" dayOfYear="8">08 janvier 1912</issue>
# <issue ark="bpt6k50399244" dayOfYear="10">10 janvier 1912</issue>
# <issue ark="bpt6k5039925j" dayOfYear="11">11 janvier 1912</issue>
# <issue ark="bpt6k5039926z" dayOfYear="12">12 janvier 1912</issue>
# <issue ark="bpt6k5039927c" dayOfYear="14">14 janvier 1912</issue>
# <issue ark="bpt6k5039928s" dayOfYear="15">15 janvier 1912</issue>
# <issue ark="bpt6k50399296" dayOfYear="17">17 janvier 1912</issue>
# <issue ark="bpt6k5039930v" dayOfYear="18">18 janvier 1912</issue>
# <issue ark="bpt6k50399318" dayOfYear="19">19 janvier 1912</issue>
# <issue ark="bpt6k5039932p" dayOfYear="20">20 janvier 1912</issue>
# <issue ark="bpt6k50399333" dayOfYear="21">21 janvier 1912</issue>
# <issue ark="bpt6k5039934h" dayOfYear="22">22 janvier 1912</issue>
# <issue ark="bpt6k5039935x" dayOfYear="24">24 janvier 1912</issue>
# <issue ark="bpt6k5039936b" dayOfYear="25">25 janvier 1912</issue>
# <issue ark="bpt6k5039937r" dayOfYear="26">26 janvier 1912</issue>
# <issue ark="bpt6k50399385" dayOfYear="27">27 janvier 1912</issue>
# <issue ark="bpt6k5039939k" dayOfYear="28">28 janvier 1912</issue>
# <issue ark="bpt6k50399407" dayOfYear="29">29 janvier 1912</issue>
# <issue ark="bpt6k5039941n" dayOfYear="31">31 janvier 1912</issue>
# <issue ark="bpt6k50399422" dayOfYear="122">01 mai 1912</issue>
# <issue ark="bpt6k5039943g" dayOfYear="123">02 mai 1912</issue>
# <issue ark="bpt6k5039944w" dayOfYear="124">03 mai 1912</issue>
# <issue ark="bpt6k50399459" dayOfYear="125">04 mai 1912</issue>
# <issue ark="bpt6k5039946q" dayOfYear="126">05 mai 1912</issue>
# <issue ark="bpt6k50399474" dayOfYear="127">06 mai 1912</issue>
# <issue ark="bpt6k5039948j" dayOfYear="129">08 mai 1912</issue>
# <issue ark="bpt6k5039949z" dayOfYear="130">09 mai 1912</issue>
# <issue ark="bpt6k5039950m" dayOfYear="131">10 mai 1912</issue>
# <issue ark="bpt6k50399511" dayOfYear="132">11 mai 1912</issue>
# <issue ark="bpt6k5039952f" dayOfYear="133">12 mai 1912</issue>
# <issue ark="bpt6k5039953v" dayOfYear="136">15 mai 1912</issue>
# <issue ark="bpt6k50399548" dayOfYear="137">16 mai 1912</issue>
# <issue ark="bpt6k5039955p" dayOfYear="140">19 mai 1912</issue>
# <issue ark="bpt6k50399563" dayOfYear="141">20 mai 1912</issue>
# <issue ark="bpt6k5039957h" dayOfYear="143">22 mai 1912</issue>
# <issue ark="bpt6k5039958x" dayOfYear="144">23 mai 1912</issue>
# <issue ark="bpt6k5039959b" dayOfYear="145">24 mai 1912</issue>
# <issue ark="bpt6k50399600" dayOfYear="146">25 mai 1912</issue>
# <issue ark="bpt6k5039961d" dayOfYear="147">26 mai 1912</issue>
# <issue ark="bpt6k5039962t" dayOfYear="149">28 mai 1912</issue>
# <issue ark="bpt6k50399637" dayOfYear="151">30 mai 1912</issue>
# <issue ark="bpt6k5039964n" dayOfYear="153">01 juin 1912</issue>
# <issue ark="bpt6k50399652" dayOfYear="154">02 juin 1912</issue>
# <issue ark="bpt6k5039966g" dayOfYear="155">03 juin 1912</issue>
# <issue ark="bpt6k5039967w" dayOfYear="158">06 juin 1912</issue>
# <issue ark="bpt6k50399689" dayOfYear="159">07 juin 1912</issue>
# <issue ark="bpt6k5039969q" dayOfYear="160">08 juin 1912</issue>
# <issue ark="bpt6k5039970c" dayOfYear="161">09 juin 1912</issue>
# <issue ark="bpt6k5039971s" dayOfYear="162">10 juin 1912</issue>
# <issue ark="bpt6k50399726" dayOfYear="164">12 juin 1912</issue>
# <issue ark="bpt6k5039973m" dayOfYear="165">13 juin 1912</issue>
# <issue ark="bpt6k50399741" dayOfYear="166">14 juin 1912</issue>
# <issue ark="bpt6k5039975f" dayOfYear="167">15 juin 1912</issue>
# <issue ark="bpt6k5039976v" dayOfYear="168">16 juin 1912</issue>
# <issue ark="bpt6k50399778" dayOfYear="169">17 juin 1912</issue>
# <issue ark="bpt6k5039978p" dayOfYear="171">19 juin 1912</issue>
# <issue ark="bpt6k50399793" dayOfYear="172">20 juin 1912</issue>
# <issue ark="bpt6k5039980r" dayOfYear="173">21 juin 1912</issue>
# <issue ark="bpt6k50399815" dayOfYear="174">22 juin 1912</issue>
# <issue ark="bpt6k5039982k" dayOfYear="175">23 juin 1912</issue>
# <issue ark="bpt6k50399830" dayOfYear="176">24 juin 1912</issue>
# <issue ark="bpt6k5039984d" dayOfYear="178">26 juin 1912</issue>
# <issue ark="bpt6k5039985t" dayOfYear="179">27 juin 1912</issue>
# <issue ark="bpt6k50399867" dayOfYear="180">28 juin 1912</issue>
# <issue ark="bpt6k5039987n" dayOfYear="181">29 juin 1912</issue>
# <issue ark="bpt6k50399882" dayOfYear="182">30 juin 1912</issue>
# <issue ark="bpt6k5039989g" dayOfYear="183">01 juillet 1912</issue>
# <issue ark="bpt6k50399904" dayOfYear="185">03 juillet 1912</issue>
# <issue ark="bpt6k5039991j" dayOfYear="186">04 juillet 1912</issue>
# <issue ark="bpt6k5039992z" dayOfYear="187">05 juillet 1912</issue>
# <issue ark="bpt6k5039993c" dayOfYear="188">06 juillet 1912</issue>
# <issue ark="bpt6k5039994s" dayOfYear="189">07 juillet 1912</issue>
# <issue ark="bpt6k50399956" dayOfYear="190">08 juillet 1912</issue>
# <issue ark="bpt6k5039996m" dayOfYear="192">10 juillet 1912</issue>
# <issue ark="bpt6k50399971" dayOfYear="193">11 juillet 1912</issue>
# <issue ark="bpt6k5039998f" dayOfYear="194">12 juillet 1912</issue>
# <issue ark="bpt6k5039999v" dayOfYear="195">13 juillet 1912</issue>
# <issue ark="bpt6k50400003" dayOfYear="196">14 juillet 1912</issue>
# <issue ark="bpt6k5040001h" dayOfYear="198">16 juillet 1912</issue>
# <issue ark="bpt6k5040002x" dayOfYear="200">18 juillet 1912</issue>
# <issue ark="bpt6k5040003b" dayOfYear="201">19 juillet 1912</issue>
# <issue ark="bpt6k5040004r" dayOfYear="202">20 juillet 1912</issue>
# <issue ark="bpt6k50400055" dayOfYear="203">21 juillet 1912</issue>
# <issue ark="bpt6k5040006k" dayOfYear="204">22 juillet 1912</issue>
# <issue ark="bpt6k50400070" dayOfYear="206">24 juillet 1912</issue>
# <issue ark="bpt6k5040008d" dayOfYear="207">25 juillet 1912</issue>
# <issue ark="bpt6k5040009t" dayOfYear="208">26 juillet 1912</issue>
# <issue ark="bpt6k5040010g" dayOfYear="209">27 juillet 1912</issue>
# <issue ark="bpt6k5040011w" dayOfYear="210">28 juillet 1912</issue>
# <issue ark="bpt6k50400129" dayOfYear="211">29 juillet 1912</issue>
# <issue ark="bpt6k5040013q" dayOfYear="213">31 juillet 1912</issue>
# <issue ark="bpt6k50400144" dayOfYear="214">01 août 1912</issue>
# <issue ark="bpt6k5040015j" dayOfYear="215">02 août 1912</issue>
# <issue ark="bpt6k5040016z" dayOfYear="216">03 août 1912</issue>
# <issue ark="bpt6k5040017c" dayOfYear="217">04 août 1912</issue>
# <issue ark="bpt6k5040018s" dayOfYear="218">05 août 1912</issue>
# <issue ark="bpt6k50400196" dayOfYear="220">07 août 1912</issue>
# <issue ark="bpt6k5040020v" dayOfYear="221">08 août 1912</issue>
# <issue ark="bpt6k50400218" dayOfYear="222">09 août 1912</issue>
# <issue ark="bpt6k5040022p" dayOfYear="223">10 août 1912</issue>
# <issue ark="bpt6k50400233" dayOfYear="224">11 août 1912</issue>
# <issue ark="bpt6k5040024h" dayOfYear="225">12 août 1912</issue>
# <issue ark="bpt6k5040025x" dayOfYear="227">14 août 1912</issue>
# <issue ark="bpt6k5040026b" dayOfYear="228">15 août 1912</issue>
# <issue ark="bpt6k5040027r" dayOfYear="246">02 septembre 1912</issue>
# <issue ark="bpt6k50400285" dayOfYear="248">04 septembre 1912</issue>
# <issue ark="bpt6k5040029k" dayOfYear="250">06 septembre 1912</issue>
# <issue ark="bpt6k50400307" dayOfYear="251">07 septembre 1912</issue>
# <issue ark="bpt6k5040031n" dayOfYear="252">08 septembre 1912</issue>
# <issue ark="bpt6k50400322" dayOfYear="253">09 septembre 1912</issue>
# <issue ark="bpt6k5040033g" dayOfYear="255">11 septembre 1912</issue>
# <issue ark="bpt6k5040034w" dayOfYear="256">12 septembre 1912</issue>
# <issue ark="bpt6k50400359" dayOfYear="257">13 septembre 1912</issue>
# <issue ark="bpt6k5040036q" dayOfYear="258">14 septembre 1912</issue>
# <issue ark="bpt6k50400374" dayOfYear="259">15 septembre 1912</issue>
# <issue ark="bpt6k5040038j" dayOfYear="260">16 septembre 1912</issue>
# <issue ark="bpt6k5040039z" dayOfYear="262">18 septembre 1912</issue>
# <issue ark="bpt6k5040040m" dayOfYear="263">19 septembre 1912</issue>
# <issue ark="bpt6k50400411" dayOfYear="264">20 septembre 1912</issue>
# <issue ark="bpt6k5040042f" dayOfYear="265">21 septembre 1912</issue>
# <issue ark="bpt6k5040043v" dayOfYear="266">22 septembre 1912</issue>
# <issue ark="bpt6k50400448" dayOfYear="267">23 septembre 1912</issue>
# <issue ark="bpt6k5040045p" dayOfYear="269">25 septembre 1912</issue>
# <issue ark="bpt6k50400463" dayOfYear="270">26 septembre 1912</issue>
# <issue ark="bpt6k5040047h" dayOfYear="271">27 septembre 1912</issue>
# <issue ark="bpt6k5040048x" dayOfYear="272">28 septembre 1912</issue>
# <issue ark="bpt6k5040049b" dayOfYear="273">29 septembre 1912</issue>
# <issue ark="bpt6k50400500" dayOfYear="274">30 septembre 1912</issue>
# <issue ark="bpt6k5040051d" dayOfYear="276">02 octobre 1912</issue>
# <issue ark="bpt6k5040052t" dayOfYear="277">03 octobre 1912</issue>
# <issue ark="bpt6k50400537" dayOfYear="278">04 octobre 1912</issue>
# <issue ark="bpt6k5040054n" dayOfYear="279">05 octobre 1912</issue>
# <issue ark="bpt6k50400552" dayOfYear="280">06 octobre 1912</issue>
# <issue ark="bpt6k5040056g" dayOfYear="281">07 octobre 1912</issue>
# <issue ark="bpt6k5040057w" dayOfYear="283">09 octobre 1912</issue>
# <issue ark="bpt6k50400589" dayOfYear="284">10 octobre 1912</issue>
# <issue ark="bpt6k5040059q" dayOfYear="285">11 octobre 1912</issue>
# <issue ark="bpt6k5040060c" dayOfYear="286">12 octobre 1912</issue>
# <issue ark="bpt6k5040061s" dayOfYear="287">13 octobre 1912</issue>
# <issue ark="bpt6k50400626" dayOfYear="288">14 octobre 1912</issue>
# <issue ark="bpt6k5040063m" dayOfYear="290">16 octobre 1912</issue>
# <issue ark="bpt6k50400641" dayOfYear="291">17 octobre 1912</issue>
# <issue ark="bpt6k5040065f" dayOfYear="292">18 octobre 1912</issue>
# <issue ark="bpt6k5040066v" dayOfYear="293">19 octobre 1912</issue>
# <issue ark="bpt6k50400678" dayOfYear="294">20 octobre 1912</issue>
# <issue ark="bpt6k5040068p" dayOfYear="295">21 octobre 1912</issue>
# <issue ark="bpt6k50400693" dayOfYear="297">23 octobre 1912</issue>
# <issue ark="bpt6k5040070r" dayOfYear="298">24 octobre 1912</issue>
# <issue ark="bpt6k50400715" dayOfYear="299">25 octobre 1912</issue>
# <issue ark="bpt6k5040072k" dayOfYear="300">26 octobre 1912</issue>
# <issue ark="bpt6k50400730" dayOfYear="301">27 octobre 1912</issue>
# <issue ark="bpt6k5040074d" dayOfYear="302">28 octobre 1912</issue>
# <issue ark="bpt6k5040075t" dayOfYear="304">30 octobre 1912</issue>
# <issue ark="bpt6k50400767" dayOfYear="305">31 octobre 1912</issue>
# <issue ark="bpt6k5040077n" dayOfYear="306">01 novembre 1912</issue>
# <issue ark="bpt6k50400782" dayOfYear="307">02 novembre 1912</issue>
# <issue ark="bpt6k5040079g" dayOfYear="309">04 novembre 1912</issue>
# <issue ark="bpt6k50400804" dayOfYear="311">06 novembre 1912</issue>
# <issue ark="bpt6k5040081j" dayOfYear="312">07 novembre 1912</issue>
# <issue ark="bpt6k5040082z" dayOfYear="313">08 novembre 1912</issue>
# <issue ark="bpt6k5040083c" dayOfYear="314">09 novembre 1912</issue>
# <issue ark="bpt6k5040084s" dayOfYear="315">10 novembre 1912</issue>
# <issue ark="bpt6k50400856" dayOfYear="319">14 novembre 1912</issue>
# <issue ark="bpt6k5040086m" dayOfYear="320">15 novembre 1912</issue>
# <issue ark="bpt6k50400871" dayOfYear="321">16 novembre 1912</issue>
# <issue ark="bpt6k5040088f" dayOfYear="322">17 novembre 1912</issue>
# <issue ark="bpt6k5040089v" dayOfYear="323">18 novembre 1912</issue>
# <issue ark="bpt6k5040090h" dayOfYear="325">20 novembre 1912</issue>
# <issue ark="bpt6k5040091x" dayOfYear="326">21 novembre 1912</issue>
# <issue ark="bpt6k5040092b" dayOfYear="327">22 novembre 1912</issue>
# <issue ark="bpt6k5040093r" dayOfYear="328">23 novembre 1912</issue>
# <issue ark="bpt6k50400945" dayOfYear="329">24 novembre 1912</issue>
# <issue ark="bpt6k5040095k" dayOfYear="330">25 novembre 1912</issue>
# <issue ark="bpt6k50400960" dayOfYear="332">27 novembre 1912</issue>
# <issue ark="bpt6k5040097d" dayOfYear="333">28 novembre 1912</issue>
# <issue ark="bpt6k5040098t" dayOfYear="334">29 novembre 1912</issue>
# <issue ark="bpt6k50400997" dayOfYear="335">30 novembre 1912</issue>
# <issue ark="bpt6k5040100f" dayOfYear="336">01 décembre 1912</issue>
# <issue ark="bpt6k5040101v" dayOfYear="337">02 décembre 1912</issue>
# <issue ark="bpt6k50401028" dayOfYear="339">04 décembre 1912</issue>
# <issue ark="bpt6k5040103p" dayOfYear="340">05 décembre 1912</issue>
# <issue ark="bpt6k50401043" dayOfYear="341">06 décembre 1912</issue>
# <issue ark="bpt6k5040105h" dayOfYear="343">08 décembre 1912</issue>
# <issue ark="bpt6k5040106x" dayOfYear="344">09 décembre 1912</issue>
# <issue ark="bpt6k5040107b" dayOfYear="346">11 décembre 1912</issue>
# <issue ark="bpt6k5040108r" dayOfYear="347">12 décembre 1912</issue>
# <issue ark="bpt6k50401095" dayOfYear="348">13 décembre 1912</issue>
# <issue ark="bpt6k5040110t" dayOfYear="349">14 décembre 1912</issue>
# <issue ark="bpt6k50401117" dayOfYear="350">15 décembre 1912</issue>
# <issue ark="bpt6k5040112n" dayOfYear="351">16 décembre 1912</issue>
# <issue ark="bpt6k50401132" dayOfYear="353">18 décembre 1912</issue>
# <issue ark="bpt6k5040114g" dayOfYear="354">19 décembre 1912</issue>
# <issue ark="bpt6k5040115w" dayOfYear="355">20 décembre 1912</issue>
# <issue ark="bpt6k50401169" dayOfYear="356">21 décembre 1912</issue>
# <issue ark="bpt6k5040117q" dayOfYear="357">22 décembre 1912</issue>
# <issue ark="bpt6k50401184" dayOfYear="358">23 décembre 1912</issue>
# <issue ark="bpt6k5040119j" dayOfYear="360">25 décembre 1912</issue>
# <issue ark="bpt6k50401206" dayOfYear="361">26 décembre 1912</issue>
# <issue ark="bpt6k5040121m" dayOfYear="363">28 décembre 1912</issue>
# <issue ark="bpt6k50401221" dayOfYear="364">29 décembre 1912</issue>
# <issue ark="bpt6k5040123f" dayOfYear="365">30 décembre 1912</issue>
# </issues>

# %% [markdown]
# <b>Résultat</b> : le calendrier du titre pour l'année 1912

# %% [markdown]
# #### Trouver les numéros publiés les jours suivant celui du document résultat

# %%
numeros = []
dates = []

# calculer le jour de publication du numéro sous la forme d'un ordinal
janvier01 = datetime.datetime.strptime("1912-01-01", '%Y-%m-%d')
diff = (dateObj - janvier01).days + 1

# chercher un numéro dans les 5 jours qui suivent
bs_content = bs(r.text, "lxml")
for i in range(5):
    jourSuiv = diff+i
    numero = bs_content.find("issue", {"dayofyear" : jourSuiv})
    if numero:
        print (f" jour : {jourSuiv} / ID : {numero['ark']}"  )
        numeros.append(numero['ark'])  
        dates.append(numero.get_text()) 
  
print (dates)
# Out:
#  jour : 172 / ID : bpt6k50399793
#  jour : 173 / ID : bpt6k5039980r
#  jour : 174 / ID : bpt6k50399815
#  jour : 175 / ID : bpt6k5039982k
#  jour : 176 / ID : bpt6k50399830
# ['20 juin 1912', '21 juin 1912', '22 juin 1912', '23 juin 1912', '24 juin 1912']

# %% [markdown]
# <b>Résultat</b> : les numéros suivants le 20 juin 1912 (inclus)

# %% [markdown]
# ### 5. Produire une revue de presse à partir d'extraits de ces numéros

# %% [markdown]
# #### Obtenir les extraits de texte (requête = 'titanic')

# %%
from PIL import Image 
import os, fnmatch

pages = []
revue = "./revue"

# Obtenir les pages concernées pour chaque numéro avec l'API ContentSearch   
for n in numeros:    
    req_url = "".join([BASESEARCH,n,'&query=titanic'])
    print ("\n... appel de l'API Gallica ContentSearch : ",req_url)
    r = requests.get(req_url)
    bs_content = bs(r.text, "lxml")
    # obtenir le numéro de page
    hits = bs_content.find_all("p_id")
    print (hits)
    pages.append(hits)
    # obtenir l'extrait de texte
    extraits = bs_content.find_all("content")
    print (extraits)
# Out:
# ... appel de l'API Gallica ContentSearch :  https://gallica.bnf.fr/services/ContentSearch?ark=bpt6k50399793&query=titanic
# [<p_id>PAG_2</p_id>, <p_id>PAG_3</p_id>]
# [<content>A Travers l’Actualité Les Astor La mort du colonel Astor sur le &lt;span class='highlight'&gt;Titanic&lt;/span&gt; appelle l’attention sur la dynastie des Astor, dont voici l’histoire : « Jacob Astor, 81, rue de la Reine, deux maisons plus loin que la salle de réunion des Amis(...)</content>, <content>Il laissait deux fils: l’aîné, Jean-Jacob second du nom, mourut en 1890 laissant à son fils William Waldorf 625 millions le cadet William mourut en 1892 laissant 350 millions à son fils Jean-Jacob celui qui vient de périr avec le &lt;span class='highlight'&gt;Titanic&lt;/span&gt;— e 1275(...)</content>]
#
# ... appel de l'API Gallica ContentSearch :  https://gallica.bnf.fr/services/ContentSearch?ark=bpt6k5039980r&query=titanic
# [<p_id>PAG_3</p_id>]
# [<content>Annale « Coloniale» En mémoire du « &lt;span class='highlight'&gt;Titanic&lt;/span&gt; » Une touchante cérémonie a eu lieu à bord du paquebot « Garmania », qui vient d’arriver(...) à New York, au moment où ce navire passait près de l’endroit où le « &lt;span class='highlight'&gt;Titanic&lt;/span&gt; » a sombré</content>]
#
# ... appel de l'API Gallica ContentSearch :  https://gallica.bnf.fr/services/ContentSearch?ark=bpt6k50399815&query=titanic
# []
# []
#
# ... appel de l'API Gallica ContentSearch :  https://gallica.bnf.fr/services/ContentSearch?ark=bpt6k5039982k&query=titanic
# [<p_id>PAG_2</p_id>]
# [<content>tombe de son mari... englouti avec le &lt; &lt;span class='highlight'&gt;Titanic&lt;/span&gt;(...)</content>]
#
# ... appel de l'API Gallica ContentSearch :  https://gallica.bnf.fr/services/ContentSearch?ark=bpt6k50399830&query=titanic
# []
# []

# %% [markdown]
# <b>Résultat</b> : les cinq extraits (et leur page) trouvés dans les numéros du 20 juin 1912 au 24 juin 1912,

# %% [markdown]
# #### Obtenir des vignettes d'extraits de texte autour des occurrences

# %%
URLiiif = []

def path_to_pil(folder, file):
    print ("--- loading image ",file,"...")
    img = Image.open(folder+file)
    return img

# extraire un fichier image à partir d'une URL iiif
def ark_to_file(list): # URL, indice du numéro
    response = requests.get(list[0]) 
    print (list[0])
    date = dates[list[1]]
    filename = "".join([revue,date])
    filename = filename.replace(" ", "_")
    if os.path.exists(filename + ".jpg"):
        filename += "+"
    filename += ".jpg"
    file = open(filename, "wb")
    file.write(response.content)
    file.close()   

print (pages)
    
# Obtenir les zones concernées sur les pages trouvées précédemment par l'API.  
# L'API est désormais appelée avec le paramètre page
for i,e in enumerate(pages):
    for p in e:
        #print (p)
        f = p.string.split("_")[1]
        req_url = "".join([BASESEARCH,numeros[i],'&query=titanic&page=',f])   
        print (f"... appel de l'API Gallica ContentSearch : document {numeros[i]}, page {f} ")
        print (req_url)
        r = requests.get(req_url)
        bs_content = bs(r.text, "lxml")
        # obtenir les coordonnées du mot dans l'OCR ALTO
        hits = bs_content.find_all("altoidstring")
        for h in hits:
            x = int(h.get("hpos")) - 200
            y = int(h.get("vpos")) - 100
            # construire la requête IIIF
            req_url = "".join([BASEIIIF,numeros[i],"/f",f,"/",str(x),",",str(y),",1200,500/full/0/native.jpg"])
            print (" -> ",req_url)
            URLiiif.append((req_url,i))
 
newpath = r'./revue' 
if not os.path.exists(newpath):
    os.makedirs(newpath)

print ("\n... extraire les vignettes IIIF")
[ark_to_file(u) for u in URLiiif]

out_paths = fnmatch.filter(os.listdir(revue), '*.jpg')
print (out_paths)
annotated_images = [path_to_pil(revue,e) for e in out_paths]
for im in annotated_images:
    print (im.filename)
    display(im)
# Out:
# [[<p_id>PAG_2</p_id>, <p_id>PAG_3</p_id>], [<p_id>PAG_3</p_id>], [], [<p_id>PAG_2</p_id>], []]
# ... appel de l'API Gallica ContentSearch : document bpt6k50399793, page 2
# https://gallica.bnf.fr/services/ContentSearch?ark=bpt6k50399793&query=titanic&page=2
#  ->  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k50399793/f2/3564,3902,1200,500/full/0/native.jpg
#  ->  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k50399793/f2/2985,3940,1200,500/full/0/native.jpg
# ... appel de l'API Gallica ContentSearch : document bpt6k50399793, page 3
# https://gallica.bnf.fr/services/ContentSearch?ark=bpt6k50399793&query=titanic&page=3
#  ->  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k50399793/f3/227,1485,1200,500/full/0/native.jpg
# ... appel de l'API Gallica ContentSearch : document bpt6k5039980r, page 3
# https://gallica.bnf.fr/services/ContentSearch?ark=bpt6k5039980r&query=titanic&page=3
#  ->  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k5039980r/f3/1251,1979,1200,500/full/0/native.jpg
#  ->  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k5039980r/f3/942,2227,1200,500/full/0/native.jpg
# ... appel de l'API Gallica ContentSearch : document bpt6k5039982k, page 2
# https://gallica.bnf.fr/services/ContentSearch?ark=bpt6k5039982k&query=titanic&page=2
#  ->  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k5039982k/f2/363,1456,1200,500/full/0/native.jpg
#
# ... extraire les vignettes IIIF
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k50399793/f2/3564,3902,1200,500/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k50399793/f2/2985,3940,1200,500/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k50399793/f3/227,1485,1200,500/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k5039980r/f3/1251,1979,1200,500/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k5039980r/f3/942,2227,1200,500/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k5039982k/f2/363,1456,1200,500/full/0/native.jpg
# []

# %% [markdown]
# <b>Résultat</b> : les vignettes centrées autour des occurrences pour les cinq extraits
